# %% [markdown]
# # Whiskey Name Normalisation and Clustering
#
# This notebook aims to identify the same whiskey across multiple reviews, regardless of whether the exact same name was used.  In the GenAI parsing I did some name metadata extraction, and we are going to leverage that along with hierarchical clustering to create a unique set of whiskies contained in the review

# %%
import json
import os
import pandas as pd
from pymongo.mongo_client import MongoClient
from pymongo.server_api import ServerApi
import certifi
from sympy.codegen.ast import continue_

uri = f"mongodb+srv://{os.getenv('whiskeydb_admin')}:{os.getenv('whiskeydb_pwd')}@whiskeyrecommender.mvfds.mongodb.net/?retryWrites=true&w=majority&appName=WhiskeyRecommender"
ca = certifi.where()

# Create a new client and connect to the server
client = MongoClient(uri,
    server_api=ServerApi('1'),
    tls=True,
    tlsAllowInvalidCertificates=False,
    tlsCAFile=ca)
# Send a ping to confirm a successful connection
try:
    client.admin.command('ping')
    print("Pinged your deployment. You successfully connected to MongoDB!")
except Exception as e:
    print(e)
# Out:
# Pinged your deployment. You successfully connected to MongoDB!

# %%
from thefuzz import fuzz
from scipy.spatial.distance import pdist, squareform
from scipy.cluster.hierarchy import linkage, dendrogram, fcluster
import numpy as np

# %%
reddit_reviews = client.reddit_reviews
parsed_docs = reddit_reviews['parsed_reviews']

whiskey_docs = [x for x in parsed_docs.find()]

# %%
names_to_cluster = set([x['whiskey_name'] for x in whiskey_docs])

# %%
len(names_to_cluster)
# Out:
# 9849

# %%
names_to_cluster
# Out:
# {'Madeira Cask Finish',
#  'Stones of Stenness 13 Single Cask Nation',
#  'Longmorn 22 1992 TWE Selection',
#  'Allt-a-Bhainne 17',
#  'Glen Broch 10',
#  'Four Grain Straight Bourbon',
#  'Speyside 44',
#  'A Midwinter Nights Dram Act 4.2',
#  'Dalmore 19 1990 Signatory',
#  '15 Signatory First Fill Sherry',
#  'Benrinnes 14',
#  "Nectar D'Or 12",
#  'Stroma Liqueur',
#  'Single Cask #4668 Peated/Port Pipe',
#  "Queen's Own Cask",
#  'Port Cask Matured',
#  'Small Batch Reserve',
#  'Glenburgie 15 Signatory',
#  'Dant Bottled In Bond',
#  "Dewar's 12",
#  'Pike Creek 10 Port Finish',
#  'Eddu Gold',
#  'Rhetoric 20',
#  'Smokey Joe',
#  'Port Charlotte Micro Provenance Cask #0005 - Virgin Oak',
#  'The Tayne',
#  '10th Anniversary (2016) Machir Bay CS',
#  '2004 Vintage Bourbon',
#  'Balvenie 14 Roasted Malt',
#  'Cask Sample',
#  'Solist Oh! So Sherried for Canada',
#  'Storm',
#  'Single Barrel',
#  'Dragon Legend',
#  'Glen Elgin 16 SMWS 85.42',
#  'SMWS 36.11',
#  'GlenDronach 14 Virgin Oak',
#  'Octomore 4.2 Comus',
#  'Cumberland Cask Experimental Cask Strength Ruby Cut',
#  "Old Scout Bourbon 9 Davidson's Pick",
#  'Arran 18 1996 Lochranza Blackadder Raw Cask',
#  'Discovery #8 Sauternes Cask',
#  'Four Roses Single Barrel Private Selection OBSQ BevMo',
#  'Bunnahabhain 12 Old Version',
#  'Deanston 18 Cognac Cask',
#  'Ben Nevis 16 Battlehill',
#  'Glen Scotia 9 SMWS 93.79 "Oiled up and frisky"',
#  'Heritage Single Barrel',
#  'Rittenhouse Rye 23',
#  "Whistlepig 10 Rye Single Barrel Broudy's Bourbonr",
#  '43 1971 Single Cask PX',
#  'Single Cask 1984',
#  'Bruichladdich Port Charlotte 13 2001 Rest & Be Thankful',
#  'Braeval 16 Distillery Reserve Collection',
#  'Boxing Hares',
#  'Linkwood 18 Rest and Be Thankful',
#  'Kilchoman 2007 Vintage',
#  'Tormore 18 1995',
#  'Cheddar Cheese',
#  'Rittenhouse Rye',
#  'Ledaig 6 Murray McDavid',
#  'Manhattan Rye',
#  'Ben Nevis 21 1996 Old Malt Cask',
#  'Great King St. Glasgow Blend',
#  'Glenburgie 18 1999 Old Malt Cask',
#  'Sweden Rock 15',
#  "Ballantine's 12 Late 70's bottle",
#  'Mortlach 18',
#  'Auchentoshan 35 1975',
#  'Ardbeg 1974 cask #3498',
#  'Imperial 18',
#  'Dalmore 25',
#  'PostModern American Single Malt',
#  'Nordic nosh',
#  'A Midwinter Nights Dram Act 5.3',
#  'Family Estate Bourbon 10 #200',
#  'Strathisla 13 Distillery Reserve Collection',
#  'Classic',
#  'Octomore 8.3',
#  'Cherrywood Smoked',
#  'Highland Park 28 1988 Cadenhead Small Batch',
#  'Wicklow',
#  'Red Tape Rhone Finish',
#  'Benrinnes 14 CS',
#  'Longmorn 26 SMWS 7.148',
#  'Mortlach 31 1987 Connoisseurs Choice - Cask Strength',
#  'Loch Lomond 21 1997',
#  'Gentleman Jack',
#  'Balblair 2005',
#  'Tullibardine 500 Sherry Finish',
#  'Bacalta',
#  'Glenfarclas 24',
#  'Forty Creek Copper Pot Reserve',
#  'Redbreast 1999 Sherry Cask for TWE',
#  'Longrow 10',
#  'Islay Blended Malt 23 TBWC',
#  "The Vintner's Trilogy French Oak Barrique",
#  'Bushmills 1608',
#  "Russell's Reserve Single Barrel Rye Liquor Barn Barrel #16",
#  'Springbank 10',
#  '29.167 "Wowf!"',
#  'Tomintoul 10',
#  'Monkey Shoulder',
#  'Aberlour 16 Cask Strength',
#  'Arran 100 Proof',
#  '17 A.D. Rattray',
#  'Laphroaig 18 1989 Old Malt Cask',
#  '15 Laimrig Batch 4',
#  'SMWS 29.154 "Camping with M*A*S*H"',
#  'Benchmark',
#  'Tamnavulin 21 1993 Old Malt Cask',
#  'Caol Ila 15 Single Barrel Ian MacLeod',
#  'Amarone Cask Finish',
#  'Great Cask Selection',
#  "Caol Ila 10 G&M Binny's Select",
#  'The Wild Geese Single Malt',
#  'Kirkland Signature 18 Speyside Sherry Cask Finish',
#  'Longrow NAS',
#  'Glen Grant 23 1992 Exclusive Malts',
#  "Russell's Reserve Single Barrel Bourbon Total Bev",
#  'Single Barrel Private Selection OBSV Fine Wine & Good Spirits',
#  'Port Ellen 22 1978',
#  'Mortlach 7',
#  "Ledaig 7 Signatory Binny's Select",
#  'Longrow 11 Single Cask',
#  'Octomore 2.2 Orpheus',
#  'Balvenie 15 Single Cask Hand Filled',
#  'Glenlivet 33 Signatory 1981/2015 TWE selection',
#  'Hayes Parker Reserve',
#  'Bunnahabhain 26 1987 Berry Brothers & Rudd',
#  'Temptation Bourbon',
#  'Bellvoye Bleu Triple Malt',
#  'Glenfarclas 17',
#  'Aberfeldy 1994 Wemyss',
#  'Springbank 13 SMWS 27.105 "Too cool for school"',
#  'Eagle Rare 10 Single Barrel Select WB Liquors #373',
#  'Christmas Edition',
#  'Old Weller Antique Private Select',
#  'Glen Garioch 1990 Samaroli',
#  'Bunnahabhain 23 1990',
#  'Laphroaig 16 1995',
#  'Springbank 12 Rum Wood',
#  "Highland Park 27 1988 Cadenhead's",
#  'Overproof',
#  'Bunnahabhain 9 SMWS 10.83 "Incredibly Awesome!"',
#  'Glen Scotia 19',
#  'Peter Arkle 2nd Edition',
#  'Secale Straight Rye',
#  'Springbank 19 1996 Fresh Rum Cask',
#  'Glen Scotia 10',
#  'Ledaig 18 TBWC',
#  'Henry McKenna 10yr SB BiB',
#  "Woodford Reserve Distiller's Select",
#  'Balvenie 42 1970 Sherry Cask',
#  "Benrinnes 17 The Cooper's Choice",
#  'Clynelish 1988 DT',
#  'Benrinnes 13 Sherry Cask',
#  "A'bunadh batch #58",
#  'Glen Moray 24 SMWS 35.145 "Lost in the dessert"',
#  'Kentucky Spirit Total Beverage',
#  'Old Fitzgerald Bottled in Bond',
#  'Bowmore 18 SMWS 3.296',
#  'GlenDronach 24 1992 Single Cask Oloroso',
#  'Black Extra Aged',
#  "Mackinlay's Shackleton",
#  'Glen Grant 25 1988 SMWS 9.88 "A Heart-Starter"',
#  'WhistlePig 10 Store Select',
#  'Glenlivet 33 1981 The Ultimate #9467',
#  'Linkwood 19 1997 K&L Signatory Vintage',
#  'Benrinnes 17 Hepburns Choice K&L',
#  'Glenfarclas 105 Cask Strength 22',
#  '29.157',
#  'Spice Tree Compass Box',
#  'Garryana 2',
#  'Oak Cross',
#  "GlenDronach 11 Manager's Cask PX Puncheon",
#  'Oban 14',
#  "Russell's Reserve 10",
#  'Canadian Club 20',
#  'Magnus Bourbon',
#  'Very Rare',
#  'Single Cask PX',
#  'Bruichladdich 11 SMWS 23.73',
#  'Balbair 9 SMWS 70.12',
#  'Glen Garioch 25 1990',
#  'Macallan 18',
#  "Clynelish 18 Hepburn's Choice",
#  'Ledaig 20',
#  'Glenrothes 1989 23 Signatory',
#  'Laphroaig 16 Douglas of Drumlanrig',
#  'Tobermory 21',
#  'GlenDronach 20 1995 Single Cask PX',
#  'Swedish Oak 2nd Edition',
#  '10 SMWS 66.65 "Holy Smokes"',
#  'Edradour 16 Bordeaux Finish',
#  'Edition No. 4',
#  'Benrinnes 20 1995',
#  'Black Label Extra Special',
#  'Blair Athol 26 Signatory',
#  'Convalmore 20 1977 Cadenhead Authentic Collection',
#  'Cuvee 382 - La Berenice',
#  'Old Fitzgerald Bottled in Bond 11 Year',
#  'Glenfarclas 25',
#  'BR5 Elements of Islay',
#  'Glen Ord 17 Signatory Cask Strength for K&L',
#  'Caol Ila 34 1982 Cadenhead Small Batch (The Nectar 10th)',
#  'Cask 667',
#  'Glenallachie 8 2008 Duncan Taylor Octave',
#  'Johnny Drum Private Stock',
#  'St. George Diamond Jubilee',
#  'Bookers Bluegill Creek',
#  "19 Cadenhead's 175th Anniversary",
#  'Kirkland Signature 7 Bourbon extra aged 9 mos in mini 2L barrel',
#  'Glen Keith 1992 Alambic Classique',
#  'Eagle Rare 10 K&L',
#  "Single Barrel Private Selection OBSO Binny's",
#  'Caol Ila 1991',
#  'Glenlivet 16 1997 K&L Selection',
#  'Croftengea',
#  'Caol Ila 11 Signatory',
#  "Sainsbury's Blended Scotch Whisky",
#  'Rosebank 17',
#  'Glenfarclas 14',
#  'Old Weller Antique 107',
#  'Snowflake Mount Bierstadt',
#  'Bunnahabhain 27 Hepburn’s Choice',
#  'Port Ruighe',
#  'GlenDronach 22 PX Sherry',
#  "Old Pulteney 8 Year Signatory Binny's Select",
#  'Bunnahabhain 26 1989 Cadenhead',
#  "Horse harnesses and mescal 'worms'",
#  'American Blended',
#  'Ledaig 19 1997 Càrn Mòr Celebration of the Cask',
#  'Peated Blackadder Raw Cask',
#  'Cu Bocan 2005',
#  'Balblair 1990 15 Dewar-Rattray',
#  'Tamdhu 8',
#  'Laphroaig 20 SMWS 29.99',
#  'Blackface 8',
#  'Colonel E.H. Taylor Four Grain',
#  'Johnny Drum',
#  'Teaninich 30',
#  'Smoked Porridge',
#  'Convict Resurrection',
#  'Oven Buster',
#  '1996 Single Sherry Cask for LMDW',
#  'Ledaig 11 2005 Signatory Cask Strength Collection (Cask 900157)',
#  'Maderensis Fumosus',
#  'Single Barrel Private Selection OBSF - Crown Liquors',
#  'Glenallachie 38 1972 Old Malt Cask',
#  "Caol Ila 22 1991 Cadenhead's",
#  'French Oak',
#  'Banff 40 1976',
#  '1999 Single Cask The Whisky Exchange',
#  'Ledaig 2004',
#  'Braeval 14 The Ultimate',
#  'Family Reserve Rye',
#  'Micro Provenance Cask #1062 Bourbon',
#  'White Oak 14',
#  '1776 Straight Rye Sherry Finish',
#  'Macallan 22 1988 Signatory',
#  'Glen Ness 8',
#  'Crater Lake Rye',
#  'Ellenstown 12',
#  'Dailuaine 34',
#  'Four Roses Single Barrel Private Selection OBSF',
#  "Distillers' Wares",
#  'Old Forester 1897 Bottled in Bond',
#  'Willett Family Estate Bourbon 9y',
#  'Tullabardine 1993-2008 Sherry Wood Finish',
#  'Glen Grant 10',
#  "Russell's Reserve Single Barrel Bourbon Otto's",
#  'Yamazaki 1986 Mizunara Butt',
#  'Bunnahabhain 31 1976 AD Rattray cask #6223',
#  "Irishman Founder's Reserve",
#  'Tobermory 21 1995 Berry Bros. & Rudd',
#  'Very Old Scout 14 Bourbon',
#  'Allt-a-Bhainne',
#  'Sherry Edition, Series 2 Fino',
#  "Cragganmore Distiller's Edition",
#  "22 1992 Cadenhead's Rum Cask",
#  'Glenfiddich 21 Winter Storm',
#  'Bruichladdich 8',
#  'Knappogue Castle 14',
#  "Auchroisk 24 Cadenhead's Small Batch",
#  'Clan MacGregor',
#  '2000 Whiskybase',
#  'Cairdeas Amontillado',
#  '17 Septendicem',
#  '228 Burgundy',
#  'Rathskeller Rye',
#  'Glen Moray 17 Rare Auld',
#  'Springbank 8 Fresh Sherry',
#  'Dominium',
#  'One Foot Cock Bourbon',
#  'Arumaticus Fumosus',
#  'Imperial 19',
#  "Robbie's Dram (Mystery Speyside)",
#  'Eagle Rare (Dekalb Liquors Pick)',
#  'Auchentoshan 18',
#  'The Glover',
#  'Laphroaig 10 Battlehill',
#  'Double Barrel',
#  'Talisker 6 Old Malt Cask',
#  'Lukas Liquors Pick',
#  'Longrow Tokaji Wood',
#  'AnCnoc 22',
#  'Glendronach 18 1995 Single Cask Tawny Port',
#  'Cragganmore 14 1997 A.D. Rattray',
#  'Port Ellen 30 9th Release',
#  'Glen Ord 9 SMWS 177.30',
#  'Laphroaig 18 SMWS 29.226 "Seaside surprise"',
#  'Highland Park 12 1988 Adelphi',
#  'Peat Monster 10th Anniversary Edition',
#  'Enlightenment',
#  'Highland Park 28 1988 Cadenhead Wood Range Port Cask',
#  'Single Barrel Private Selection OESQ Kreston',
#  'Arran Madeira Cask Finish',
#  'The Swedish Whisky',
#  'Bullrun 10 Pinot Noir',
#  'Bunnahabhain 13 1997 Heavily Peated',
#  '15 Hart Brothers',
#  "Baker's 107",
#  'Very Old Scout 11 Bourbon',
#  'Westchester Pot Distilled Wheat Whiskey',
#  'Clynelish Distillery Bottling',
#  'Double Rye /r/bourbon Campfire Barrel',
#  "John's Lane",
#  'Akashi Single Malt',
#  'Iwai Japanese Whisky',
#  'Knockando 25',
#  'Tamdhu 34',
#  'Palm Ridge Reserve Florida Rye Whiskey',
#  'Teaninich 12 - Bottling by Lombard',
#  'Dailuaine 11 SMWS 41.68',
#  'Glen Garioch 15 Sherry Cask Matured',
#  'Sherry Cask Release',
#  'Abraham Bowman High Rye',
#  'Tomintoul 14 Portwood Finish',
#  'Bruichladdich 10 2003 Malts of Scotland',
#  'Glen Breton 10 Ice Cask Strength',
#  'Indian Single Malt',
#  'Longrow Single Cask 9y First Fill Sauternes',
#  'Karuizawa 1962 cask #6426',
#  'Heritage Collection 8th: Wheat Whiskey',
#  'Jewel/Osco Kentucky Straight Bourbon Whiskey',
#  'Casares Argentine Malt',
#  'Edradour 15 The Fairy Flag',
#  'Old Scout Bourbon 12',
#  'Braeval 12',
#  'Jim Beam Signature Craft 12',
#  'Young',
#  'Coleburn 14',
#  'Glenturret 11',
#  'Bladnoch 1987 Signatory',
#  'Bunnahabhain 13 Marsala Finish',
#  'Glen Moray 20 SMWS 35.138',
#  'Cipher',
#  '2008 Distillery cask',
#  'Irish American 10',
#  'Linlithgow 211982',
#  'Elijah Craig 12 Year',
#  'Stronachie 10',
#  'Paul John Edited',
#  '10 SMWS 58.17 Not Shaken, Not Stirred',
#  'Finlaggen Cask Strength',
#  'Abraham Bowman #15 - Gingerbread Cocoa Finished',
#  'Very Special Old Fitzgerald',
#  'Kilchoman 2009 Single Cask PX Finish',
#  "Distiller's Edition Special Release C-si-2-475",
#  'Single Barrel Private Selection OBSO Argonaut',
#  'Bruichladdich 25 Signatory Refill Sherry',
#  'Ardbeg & Craigellachie Double Barrel',
#  'Bombergers Declaration',
#  'Bulleit Cask Strength',
#  'Hirsch 16 Gold Foil',
#  'Caol Ila 11',
#  'GlenDronach 19 1993 Single Cask PX',
#  '21st Anniversary LE',
#  'Dark Batch',
#  '100 Pipers',
#  'Vineville',
#  'Port Ellen 22',
#  'Hanyu 2000 The Final Vintage',
#  'Whisky-Fässle XO Blended Malt for KWM',
#  'Glenfiddich 21 Gran Reserva Rum Cask',
#  'Johnnie Walker White Walker',
#  'Port Charlotte 13 2001 Rest & Be Thankful',
#  'Chita Single Grain',
#  "Caol Ila 6 Hepburn's Choice Sherry",
#  "Russell's Reserve Single Barrel Bourbon Lukas Liquor",
#  'Brora 21 1981 Old Malt Cask',
#  'Caol Ila 32 CS Sovereign',
#  'Colonel EH Taylor Barrel Proof (128.1)',
#  'Rittenhouse Rye DSP 354',
#  'Peat Monster Cask Strength',
#  'Teaninich 32',
#  'Single Barrel Private Selection OBSV France 44 pick',
#  'Loch Gorm',
#  'Octomore 9.3',
#  'Craigellachie 2006 12 Year Old "Sovereign" K&L',
#  "Visitor's Miniature",
#  'Tomatin 12 French Oak',
#  'Cider Cask',
#  'Single Barrel Private Selection OBSK',
#  'American Prairie Reserve',
#  'Ellenstown 12 Cask Strength',
#  '16 Duncan Taylor Dimensions',
#  'Bourbon Batch 008B',
#  "Dalmore 22 Cadenhead's Authentic",
#  'Arkansas Bourbon Whiskey',
#  'Cask Collection Sherry Reserve Cask',
#  'Springbank 20 Fresh Sherry',
#  'Aberlour 26 1989 Carn Mor',
#  'XO',
#  'Craigellachie 18 1995',
#  'Garrison Brothers Single Barrel',
#  'Craigellachie 7 The Octave',
#  'Tamdhu 2008 Carn Mor',
#  "Devil's Cask Batch 3",
#  'Cask Collection: Select Cask',
#  'Littlemill 21 First Release',
#  'Benrinnes 14 Whisky Broker',
#  'Heaven Hill 20 Cadenhead',
#  'Famous Grouse 12',
#  'Ballechin 11 First Fill Manzanilla Signatory',
#  'Jim Beam Black 6',
#  '1998 Single Cask #5172 PX/Triple-Distilled',
#  'Ceòbanach',
#  '25 Signatory',
#  'Unpeated Solera Bottle',
#  'Old Reserve',
#  'Single Barrel Select OLC Pick Barrel #17-0657',
#  "Bernheim 7 McScrooge's store pick",
#  'Peated Quarter Cask',
#  "Highland Park 8 MacPhail's Collection",
#  'Balmenach 1988',
#  'Dark Cove Committee Release',
#  'Glenfiddich 19 Age of Discovery Bourbon Cask',
#  "Braes O'Glenlivet 18",
#  'Widow Jane "whiskey distilled from a rye mash" batch 12',
#  'Movember',
#  'Yamazaki 1984',
#  'Miyagikyo "Malty & Soft" Distillery Limited Edition',
#  '@#$%^& (Eminent)',
#  'Glenrothes 1987',
#  'Bunnahabhain 11 2001 signatory sherry',
#  'Glenfiddich 21 Gran Reserva',
#  'Ardmore 1996 G&M',
#  'Vintage 2003 Chardonnay Cask',
#  'Longmorn 1964',
#  'Three Ships 15 Pinotage Cask Finish',
#  'Old Forester Bonded Split DSP',
#  'Bank Note 5',
#  'James E. Pepper 1776 Straight Bourbon',
#  'Ledaig 9 SMWS 42.29 "Marvelous Maritime margaritas"',
#  'Kilchoman 5 Single Cask Bourbon',
#  'Macallan 10',
#  "10 SMWS 13.47 It's a knockout",
#  'Glenlivet 33',
#  'Authenticus 25',
#  'Bunnahabhain 20 Cadenhead’s',
#  "Glenturret 11 The MacPhail's Collection",
#  'Blended Canadian',
#  'O.K.I Bourbon 10 Antique Barrel',
#  'Deanston 20 Oloroso Cask',
#  'Fettercairn 28 1988 Cadenhead',
#  'Family Estate Rye 12 Gift Shop Barrel #837',
#  'Tamdhu 10 Signatory Cask Strength',
#  'Secret Stills 4.15',
#  'Hazelburn 13 Oloroso',
#  'Tormore',
#  'Pure Kentucky XO',
#  'Dickel 9 Year Twin Liquors Single Barrel Select',
#  'Double Rye Manhattan Barrel Finish',
#  "J.P. Wiser's Dissertation",
#  'Conecuh Ridge',
#  'Oban 18',
#  'Coleburn',
#  'Henry McKenna 10 Single Barrel Barrel No. 83',
#  "10 Cask Strength Signatory Binny's",
#  'Golan Heights Single Malt',
#  "Russell's Reserve Single Barrel Bourbon Discount MKE",
#  'Lagavulin 2012 Distillers Edition',
#  'Glen Moray 21 1991 Master of Malt',
#  'Juras 1997 G&M',
#  'Ardbeg 1998 Cask Sample',
#  'Lot No. 40 Cask Strength',
#  "Manager's Choice",
#  'Caperdonich 39 1977 Cadenhead',
#  'Grooves Committee Release',
#  'Bunnahabhain 12',
#  'Masters Collection New Cask',
#  'Old Scout Bourbon 10 - Maple Stax',
#  'Ember',
#  'First Growth Cuvee E Sauternes',
#  'Arran 7',
#  '1990/25 Sherry Cask Edition',
#  'Glenlivet 1997 Signatory Vintage',
#  'Bourbon Port Finish Batch 4',
#  'Oloroso Wheat Whiskey',
#  'Aberfeldy 12 Year Old',
#  'Ledaig 11 2005 Exclusive Malts',
#  'Highland 2005 Kintra',
#  'Highland Park 12 SMWS 4.178',
#  'Franklin Wine And Spirits',
#  'Speyside 17',
#  'Virginia Black',
#  'Family Estate Rye 8y',
#  'Glenlivet 9',
#  'Glenmorangie 12 Quinta Ruban',
#  'SMWS 66.73 "Midnight feast at the pony club camp"',
#  'Caskmates Stout Edition',
#  'Coffey Grain',
#  "Clynelish 1990 Cadenhead's Cask Ends",
#  "J.P. Wiser's Last Barrels",
#  'Chapter 6',
#  "Hepburn's Choice K&L",
#  'Stalk and Barrel Single Malt',
#  'Single Barrel Bourbon Crusaders',
#  '114',
#  'Glen Scotia 12 Refill Sherry',
#  'Feis Ila 2016',
#  'Highland Light',
#  "Tain L'Hermitage 1975",
#  'Potomac',
#  'Pro$hibition Macvin Single Cask',
#  'Royal Brackla Exclusive Cask All Bourbon',
#  'Rendezvous Rye (Quady Port Finish)',
#  'J. Riddle Peated Bourbon',
#  "Master's Keep Revival",
#  'Benromach 10 100 Proof',
#  'Port Ellen 26y c1983 Old Bothwell #220 54.9%',
#  'Port Maturation Cask Strength',
#  "Craigellachie 22 Douglas Laing's Old Particular Refill Sherry Butt DL12717",
#  "Private Select Binny's",
#  'Bunnahabhain 25 Adelphi',
#  'Beer Barrel Bourbon',
#  'Jack Daniels 150th',
#  'BenRiach 10',
#  'Old Heaven Hill Bottled in Bond Gold Label',
#  'Glenrothes 1994',
#  'Dallas Dhu 22',
#  'Work In Progress 4',
#  'Toasted Applewood Stave Finished Straight Rye',
#  'Fusion',
#  'Arran 19 Single Cask Bourbon',
#  'Blair Athol 11',
#  'An Oa',
#  'Glenburgie 21 1995 Cask Strength Cask 6346',
#  'North British 18 1979 Signatory',
#  'DoubleWood',
#  'Guckenheimer',
#  'Royal Lochnagar 23 Rare Malts',
#  'Barrow',
#  "18 Cadenhead's Authentic",
#  'Inverleven 1984',
#  'Signatory 18y cask 19504',
#  'SMWS 36.75',
#  'Whistlepig 10 Year TPS Pick',
#  'Rye Batch #1',
#  'Linkwood 29 1985 K&L Selection',
#  '25 Single Barrel',
#  'Single Barrel Private Selection OBSQ HiTime',
#  'Four Roses Single Barrel Private Selection OESK',
#  'Laphroaig 16 SMWS 29.198',
#  'Caribbean Cask',
#  'SMWS 33.124',
#  "A'bunadh batch #60",
#  'An Cladach',
#  'Kilkerran Work In Progress 4',
#  'Very Old Barton Bottled in Bond 6',
#  '12 Gold Seal',
#  'Edradour 13 Natural Cask Strength Sherry',
#  'Glenothes 10',
#  'Glenallachie 8',
#  'Stagg Jr.',
#  'True Blue 100',
#  'Highland Park 1995',
#  "Strathclyde 25 Cadenhead's",
#  'Caol Ila 18 Sassicaia Wood Finish',
#  'Hazelburn 13 Oloroso Cask Matured',
#  'Midleton Very Rare',
#  "Family Estate Bourbon 9 #2063 Sendik's Food Market",
#  'Speyside 25 1991',
#  'Linkwood 7 1998',
#  "Russell's Reserve Single Barrel Bourbon Cool Springs Wine",
#  'Solist Port Cask',
#  'Akashi White Oak Blend',
#  "Littlemill 1990 Berry's",
#  '15y Feis Ile',
#  'Bunnahabhain 10 Signatory',
#  "Single Barrel Private Selection OESK Hazel's",
#  'Elijah Craig Barrel Proof Batch 8',
#  'Ambassador Deluxe',
#  'Chivas Regal 12',
#  'Ledaig 18 1994 Exclusive for Co-op Wines & Spirits',
#  'Beyond Duplication',
#  'Caol Ila 12 1991 Old Malt Cask',
#  'Haig Club',
#  'Single Barrel Private Selection OBSF Louisville Bourbon Hounds Birthday Barrel',
#  'BenRiach 16 1996 Single Cask PX Finish',
#  'Glenfiddich 18',
#  'Highland Queen',
#  'Bunnahabhain 1984',
#  'Bushmills Black Bush',
#  'Benrinnes 11 1997 Signatory Hogshead',
#  'Kilkerran 11 Work In Progress',
#  'Glenlivet 15 French Oak Reserve',
#  'Laphroaig 15 (200th Anniversary)',
#  'McIntyre Blended Scotch',
#  "Russell's Reserve Single Barrel Bourbon K&L",
#  'Ballechin 11 2005 SFTC Bordeaux',
#  "Blender's Batch Triple Grain American Oak",
#  'The Laddie Ten Second Edition',
#  'SMWS 33.134 "Peat roasted pig Hawaiian style"',
#  'AnCnoc Rascan',
#  'Early Times 150th Anniversary 100 proof',
#  'Port Ellen 26 Old Malt Cask',
#  'Hibiki 17',
#  'Auchroisk 18 1994 Old Malt Cask',
#  'Experimental Collection 1993 Rediscovered',
#  'Artein',
#  'Speyside 43 1973',
#  'Glenallachie 8 1991 Signatory',
#  'Port Dundas 34',
#  'Bunnahabhain 21 The Maltman',
#  'Heart of Gold',
#  'Old Pulteney 15',
#  'Glencraig 33 Ducan Taylor Rarest of the Rare',
#  '12 Herodotus Fumosas',
#  'Glenburgie 19',
#  "Nathan Stone's Private Stock",
#  'Springbank 12 Cask Strength Batch 9',
#  'Rundlets & Kilderkins',
#  'Tyrconnell 10 Madeira Cask Finish',
#  '10 Original',
#  'Bunnahabhain 10',
#  'Black Corbie',
#  'Clynelish 16 1997 Master of Malt',
#  'Widow Jane 8',
#  'Origine',
#  'Balblair 1990 25',
#  "Blanton's Black",
#  'Balblair 21 Gordon & MacPhail Cask Strength cask #1962',
#  'Laphroaig 22 SMWS 29.129',
#  "Clynelish Distiller's Edition",
#  "Bunnahabhain 32 1979 Berry's Own Selection",
#  'Tamdhu 17 1995',
#  'Arran 20 Single Cask #1226',
#  'Reverse Double',
#  'Cask Strength Batch 2',
#  '12 Elixir',
#  'VAT Weller 12 and Dry Fly 120 proof wheat 50/50',
#  'Bowmore 1994 Single Malts of Scotland',
#  'Hopped',
#  'Bruichladdich 1998 Manzanilla',
#  'Chivas Regal Extra',
#  "Kentucky Spirit McScrooge's store pick",
#  'Caol Ila 1994 Sherry G&M CS',
#  'Cask Strength',
#  'Bruichladdich 21 Signatory 1992 Cask #3657',
#  'Caperdonich 19',
#  "Cooper's Mark",
#  'Springbank 20 CS Rum Cask',
#  'Sherry Oak',
#  'Old Scout Bourbon 10 Bounty Hunter',
#  'The Gauldrons Campbeltown Blended Malt DL',
#  'Mortlach 10',
#  'Temple Bar 15 Single Malt',
#  'Caol Ila 11 1989',
#  'Creative Whisky Co. 1980 35 Year Exclusive Blend',
#  'Allardice 18',
#  'Alchemist',
#  'Glendronach 12 2003 Single Cask',
#  'Tobermory 21 1995 Toronto Whisky Society Single Cask',
#  'Peated Solera bottle',
#  'Jameson 12',
#  'Octomore 4.2_167 Comus',
#  'Collingwood 21',
#  'Singleton of Dufftown 15',
#  'Benromach 10',
#  'Fine Blend Malt extra old',
#  'Benrinnes 10 2007 Old Particular Shiraz Finish',
#  'Elijah Craig Small Batch',
#  'Caledonia',
#  '2005 Archives, 7 Old',
#  'Cowboy Bourbon',
#  'Garryana 2016 Edition 1',
#  'Macallan 12 Sherry',
#  'A Midwinter Nights Dram Act 2.1',
#  'Glen Grant 13 Old Masters',
#  "Corn N' Oil",
#  'Single Barrel Reserve K&L #5300',
#  'Double Rye (boulevardier 1yr 5mo)',
#  'Port Charlotte Scottish Barley',
#  'Yellow Spot 12',
#  'Forty Creek Port Wood Reserve',
#  "Single Barrel Private Selection OBSV O'Hara's Wine and Liquors selection",
#  "Russel's Reserve HyVee Wine",
#  "A'bunadh batch #41",
#  'Single Barrel Private Selection OESK Ledger Liquors',
#  'Inchmurrin 10 Berry Bros & Rudd',
#  'Longrow 10 100 Proof',
#  'Octomore 2005 Cask Sample',
#  'Single Barrel 2001',
#  'Black',
#  'Blood Oath Pact 3',
#  '33 Asta Morris 1977',
#  'Eagle Rare 10',
#  "Wathen's Single Barrel",
#  'Barrel Proof Batch A118',
#  'Couvreur 12 Overaged Malt Whiskey',
#  'Kilchoman 4 Single Cask Bourbon #440/10',
#  'Stronachie 31 1976',
#  'Vintage 23 Rye',
#  "A'bunadh batch #56",
#  'Selection 25 Rye',
#  '11 Hart Brothers',
#  'Enigma',
#  'Three Rivers Tokyo Blended Malt',
#  'Laphroaig 16 Old Particular',
#  'BenRiach 1994 cask #806',
#  'Dalmore 40',
#  'Barrell Whiskey Batch 004',
#  'Makura Wood In Progress',
#  'Bunnahabhain 34 1980 Single Malts Of Scotland',
#  "Wight's Maryland Straight Rye 5",
#  "Port Ellen 23 McGibbon's Provenance",
#  "McCarthy's Oregon Single Malt",
#  'Hellyers Road 10',
#  'Blair Athol 1998',
#  'Glen Moray 13 SMWS 35.165 "Variety - the spice of life"',
#  'Laphroaig 11 Signatory',
#  'Elijah Craig Barrel Proof Batch 3 133.2 Proof',
#  'Forty Creek Barrel Sample Malted Barley',
#  "A'bunadh batch #49",
#  'Strathmill 20',
#  "Linkwood 'Vanilla Zest'",
#  'Caol Ila 21 SMWS 53.216',
#  'Authenticus',
#  'Machrie Moor batch 4',
#  'Auchroisk 17 2000 Jewels of Scotland',
#  'Rare Breed 03-RB',
#  'Baker’s 7',
#  '34 Batch 8',
#  'Balblair 11 SMWS 70.14',
#  'Four Roses Single Barrel Private Selection OESF',
#  'Organic Rye Hickory Finished',
#  'McClelland Highland',
#  'Old Weller Original Gold Vein',
#  'Family Estate Rye 25 Gift Shop Barrel #1780',
#  'Georgia Moon Corn Whiskey',
#  '1997 Gordon & MacPhail',
#  'SMWS 10.83 "Incredibly Awesome!"',
#  'Arran 7 Private Cask',
#  '15 Single Barrel',
#  'Arran 15 Single Cask',
#  'Caol Ila 14 Cadenhead Small Batch',
#  'Solera Vatted',
#  'Edition No. 1',
#  'Resurrection Dram',
#  'Straight Bourbon Whiskey finished in Port Wine Casks',
#  'Ledaig 1973',
#  'Miyagikyo 10',
#  'Gooderham & Worts 17 Little Trinity',
#  'Cream of Kentucky 11.5 Year',
#  'Blended Scotch',
#  "Hibiki Japanese Harmony Master's Select",
#  'Millstone 12 Sherry Cask',
#  'Pro$hibition Vin Jaune Single Cask',
#  "Bruichladdich 21 Cadenhead's",
#  "Single Barrel Binny's Pick 3901a",
#  'A Midwinter Nights Dram Act 3.3',
#  'Mortlach 17 1995',
#  'Septendicium',
#  'Bowmore 15 Mariner',
#  'Glenfarclas 24 1990 K&L bottling',
#  'Old Scout Bourbon 11 #4139',
#  'Original',
#  'Ben Nevis 17 Exclusive Malts',
#  'Blair Athol Distillery Only',
#  'Cairdeas Fino',
#  'Auchentoshan 15 Old Malt Cask',
#  'Ouroboros',
#  'Port Askaig 16',
#  "Ledaig 19 Cadenhead's Single Barrel",
#  'Single Cask for KWM Cask #440',
#  'Scottish Barley The Classic Laddie',
#  'Laphroaig 13',
#  'Edradour 2003 Sauternes Cask Blind',
#  'Islay Blended Malt 1997 The Octave',
#  'Micro-Provenance',
#  'Winter 2016',
#  'Ledaig 9 Signatory Vintage Sherry',
#  'Drumguish 5',
#  'Edradour 11 Chateauneuf du Pape Finish (Binny’s)',
#  'Lagavulin 25 1991 Single Cask Charity Bottling',
#  'Mist 17',
#  'Dálvve',
#  'Darkest Before Dawn',
#  'Fettercairn 2006/2017 Madeira Finish',
#  'Clynelish 29 SMWS 26.102 "Pomanders in a Lady\'s Parlour"',
#  'Single Barrel Private Selection OESK K&L',
#  'Elmer T. Lee',
#  'Glen Breton 17 Ice Cask Strength',
#  'Breath of Speyside',
#  'Glencadam 10',
#  'Longmorn 18 1997 Wemyss Malts - Bittersweet Barley',
#  "Mortlach 19 1994 Binny's Selection",
#  'Barrell Bourbon Batch 005',
#  'Like a hot coal in the mouth',
#  'G7.10 "The Texan tea party"',
#  'Bruichladdich 19 1992 Signatory',
#  'Balmenach 26 1988',
#  'Bushmills 16',
#  'The Monarch',
#  'Deanston 9 2008 Bordeaux Red Wine Cask',
#  'Knob Creek Single Barrel 120 Ashland Beverage Center',
#  '28 1989 Antique Lions of Spirits',
#  'Spectrum Batch 004',
#  'Tomatin 36 Batch 4',
#  "Caol Ila 11 G&M Binny's Select",
#  'Ledaig 2004 Cask Strength',
#  'Dailuaine 8 SMWS 41.54',
#  "Glen Spey 19 Cadenhead's",
#  'Bunnahabhain 13 2004 Moine Brandy finish',
#  'Glenmorangie 10 SMWS 125.59',
#  'Single Pot Still Virgin Oak Cask 83785',
#  'Pittyvaich 13',
#  'Tamnavulin 1993 Old Malt Cask',
#  'Single Barrel Private Selection OBSO Liquor Barn',
#  "Booker's Bourbon Batch 2016-01E",
#  'Mosswood Barrel Aged American Whiskey - Espresso Barrel',
#  'Dalmore 15 Alexander Murray',
#  'Edradour 12 Port Wood Finish Straight From The Cask',
#  'Bowmore 14 AD Rattray',
#  'Brora 30 Sherry Single Barrel K&L Exclusive',
#  'Glen Deveron 20',
#  'Springbank 12 Cask Strength Batch 6',
#  'Dalmore 16 Whisky Brokers',
#  'Amrut Single Malt Whisky',
#  'Select Reserve Black Barrel',
#  'Defiant Rye Whisky',
#  'Loch Lomond 21',
#  'Benrinnes 12 1999',
#  'Longrow Red 11 Australian Shiraz',
#  'Inchmurrin Madeira Wood Finish',
#  'Edradour 10 2006 Super Tuscan Cask',
#  'Mortlach 18 1998 Signatory Vintage TWE Selection Oloroso Sherry Finish',
#  '14 1998 Single Cask Virgin Oak',
#  'Torran 12',
#  "A'bunadh batch #32",
#  'Old Forester',
#  "Single Barrel Private Selection OESK - Andy's Market",
#  'Old Fitzgerald Prime',
#  '25 1990 Old Particular',
#  'Laphroaig 18 SMWS 29.208',
#  'Bourbon Cask Distillery Exclusive',
#  'Glenlivet 16 Nadurra',
#  'Elijah Craig Barrel Proof Batch C917',
#  'Nikka Taketsuru 21',
#  'Imperial 1996 G&M',
#  'Wild Turkey 12 Year "Faux Split Label"',
#  'Family Estate Rye 4y',
#  'Glenrothes 1988 Archives',
#  'Kilchoman 2007 Single Cask Bourbon',
#  'Old Parr Superior',
#  'Virgin Oak Finish Single Cask',
#  'Aultmore 9 2008 The Sovereign K&L',
#  'Old Pulteney 1990 Limited Edition',
#  'Barrel Room Option Sherry Single Cask',
#  "Glendullan 1996 Cadenhead's Small Batch",
#  "Russell's Reserve Single Barrel Bourbon Shawan",
#  "A'bunadh batch #39",
#  'Auchroisk 1997 CM',
#  'Bunnahabhain 23 1989 Great Cask Series',
#  'Port Charlotte 9 2006 Valinch Cask Exploration 09',
#  'Double Rye Quady Black Muscat Finish',
#  'Aberlour 11 Duncan Taylor NC2',
#  'Port Charlotte 11',
#  '14 Port Wood',
#  'Benriach 10 2007 Single Cask Peated/Bourbon',
#  'Benriach 19 Single Cask peated/oloroso',
#  "Hochstadter's 16 Year Rye",
#  "Grant's 18",
#  'Glenfarclas 24 Family Cask Astor Wine',
#  'Highland Black 8',
#  'Irishman 70',
#  'Bunnahabhain 12 Wemyss "Chocolate Honeycomb"',
#  'Provenance',
#  'Bib & Tucker 6 Small Batch',
#  'Project XX',
#  'Brandy Cask Finish',
#  'Chivas Regal 25',
#  'Single Barrel Private Selection OESK',
#  'Cleveland Bourbon Whiskey',
#  'Glenglassaugh',
#  'Kanosuke New Born',
#  'Caol Ila 29 55.5',
#  'GlenDronach 16 1996 Single Cask PX',
#  'Glenburgie 17 1998 SMWS 71.42 - "Sinbad preparing for a journey"',
#  '1994 Single Cask Distillery Exclusive',
#  'Loch Dhu 10',
#  '12 Arumaticus Fumosus',
#  'Dailuaine 15 Whisky For Leiden',
#  'The Infamous 22',
#  'Ardmore 11 SMWS 66.84',
#  'Single Barrel Private Selection OESF Loch & K(e)y',
#  'Aultmore 25 1990 whiskybroker',
#  'Larceny Small Batch Bourbon',
#  "J.P. Wiser's 35 Year Old Cask Strength",
#  'Lonach 39',
#  '18 Oloroso Cask',
#  'Bunnahabhain 2006',
#  'Old Pulteney 25',
#  'Woodford Reserve',
#  'Writer’s Tears Red Head',
#  "Highland Park 25 Cadenhead's",
#  'Cairdeas 2011 Ileach',
#  'Cask Strength Reserve - Batch 6',
#  'Bowmore 17 SMWS 3.251',
#  'White Dog',
#  'Laphroaig 12',
#  'Single Barrel Reserve: Fine Wine and Spirits Pick',
#  'Bunnahabhain 22 1989 AD Rattray cask #5835',
#  'Wilderness Trail Single Barrel',
#  'Linkwood 12 Flora & Fauna',
#  'Double Single Compass Box',
#  'Glen Grant 32 1975 Malt Trust',
#  'Glen Keith 19 Signatory',
#  'Sherry Wood',
#  'Glenfarclas 1981 The Family Casks',
#  'Cragganmore 13',
#  'Aberlour 25',
#  "Locke's Blended Whiskey",
#  'Bruichladdich 1994 Full Strength 2nd Ed',
#  'Ben Nevis 14',
#  'Cairdeas 2014 Amontillado',
#  'Highland Park 26 Cadenhead Small Batch',
#  'Glendronach 12',
#  'Rebellion Bourbon',
#  'Caol Ila 12 Unpeated Cask Strength',
#  'Colorado Whiskey',
#  'Bunnahabhain 28 Wemyss Malt "Scallop Diver\'s Dram"',
#  'Glengoyne 21 1996',
#  "Single Barrel Private Selection OESK Randall's",
#  'Loch Lomond',
#  'Jameson 12 Special Reserve',
#  'Glen Grant 25 SMWS 9.89 "Balanced and Harmonius"',
#  'Ardmore 5',
#  'Wild Turkey Rare Breed 116.8',
#  'Bourbon Cask Reserve',
#  'Cragganmore 17',
#  'Balvenie 14 Sherry',
#  'Devils Cut',
#  'Teaninich 23 Rare Malts',
#  'Samsara',
#  'Lagavulin 8',
#  'Mannochmore 28 1988 Sansibar',
#  'Elijah Craig Small Batch Oak Liquor Cabinet Pick',
#  "Bunnahabhain 14 2002 Cooper's Choice",
#  "Highland Park 1985 Scott's Selection",
#  'Club Bottling V: 10 ex-bourbon/oloroso',
#  'Glen Scotia 14 G&M',
#  '18 Year Old',
#  'Auchentoshan 13 Exclusive Casks',
#  'Toki',
#  'Glenfarclas 28 1988 Cadenhead',
#  'Asian Delight',
#  'Craigellachie 14 Flora & Fauna',
#  'George Dickel 9 Single Barrel',
#  'Madeira Wood Finish',
#  'Black Label Whiskey',
#  'Old Ballantruan',
#  'Adela',
#  'Dionysus Tea Whisky',
#  "Locke's 8",
#  'Blair Athol 19 Year Cask Strength',
#  'Highland Park 21 1987 Duncan Taylor Rare Auld',
#  'Highland Park 1989',
#  'Barrell Craft Spirits Bourbon 15 Year Old Cast Strength',
#  "A Midwinter Night's Dram - Act 6 Scene 1",
#  'Inchmurrin 21 1993 Signatory Cask Strength',
#  'Bruichladdich 24 1992 Cadenhead',
#  'Tomintoul 15 1999 AD Rattray Cask #9289',
#  'Kilchoman Feis Ile',
#  'Small Batch Bourbon',
#  'Glenfiddich 15 Hand Filled',
#  'Eades Speyside Double Malt',
#  'Glenfarclas 1989 Family Cask #7300',
#  'Ardmore 15 Exclusive Malts',
#  'Cairdeas 2012 Origin',
#  'Scapa 10 Gordon MacPhail',
#  'Exclusive Malts 7',
#  'Blue Label Japanese Edition',
#  'Chronicles 41',
#  'Port Charlotte PC7 Sin An Doigh Ileach',
#  'Laphroaig 14 1998',
#  'Bunnahabhain 17 1988 Malt Trust',
#  ...}

# %%
def string_distance(u, v):
    similarity = fuzz.token_sort_ratio(u, v)
    return (100 - similarity)/100 # Convert similarity (0-100) to distance (100-0)

# %%
names_array = np.array(list(names_to_cluster)).reshape(-1,1)

# Create a condensed distance matrix using pdist
distance_matrix = pdist(names_array, lambda x,y: string_distance(x[0],y[0]))

# %%
linkage_matrix = linkage(distance_matrix, method="ward")

# %%
clusters = fcluster(linkage_matrix, t=0.15, criterion="distance")

# %%
whiskey_df = pd.DataFrame(list(zip(names_to_cluster, clusters)), columns=["name", "cluster"])

# %%
whiskey_df.cluster.value_counts()
# Out:
# cluster
# 4682    25
# 3792    15
# 3432    15
# 2686    12
# 3309    12
#         ..
# 7104     1
# 3464     1
# 697      1
# 5054     1
# 258      1
# Name: count, Length: 7163, dtype: int64

# %%
whiskey_df.query('cluster == 2487')
# Out:
#       name  cluster
# 5764  1+11     2487

# %%
whiskey_df.sort_values(by='name')
# Out:
#                                    name  cluster
# 9711                  .36 Texas Bourbon      878
# 6607                             1 of 3     3445
# 5764                               1+11     2487
# 8410                                 10     2515
# 2615                10 Bit House Saloon      222
# ...                                 ...      ...
# 8296  barrel 3493 cask strength bourbon     4276
# 2422                       custom blend     1412
# 9648                     ex-Bourbon Oak      895
# 9789                                rī1     2513
# 8597             the exclusive blend 35     6209
#
# [9849 rows x 2 columns]

# %%
plt.figure(figsize=(10, 5))
dendrogram(
    linkage_matrix,
    labels=strings,
    leaf_rotation=45,
    leaf_font_size=12
)
plt.title("Hierarchical Clustering of Strings")
plt.xlabel("String")
plt.ylabel("Distance")
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[15], line 1
# ----> 1 plt.figure(figsize=(10, 5))
#       2 dendrogram(
#       3     linkage_matrix,
#       4     labels=strings,
#       5     leaf_rotation=45,
#       6     leaf_font_size=12
#       7 )
#       8 plt.title("Hierarchical Clustering of Strings")
#
# NameError: name 'plt' is not defined

# %%
all_review_df = pd.DataFrame(whiskey_docs)

# %%
all_review_df
# Out:
#                             _id  year     distillery disillery_region  \
# 0      678ee1a072bc0c28adb7679a  2012        Unknown            Blend
# 1      678ee1a072bc0c28adb7679b  2012     100 Pipers            Blend
# 2      678ee1a072bc0c28adb7679c  2018           1792         Kentucky
# 3      678ee1a072bc0c28adb7679d  2017         Barton         Kentucky
# 4      678ee1a072bc0c28adb7679e  2018           1792         Kentucky
# ...                         ...   ...            ...              ...
# 31030  678ee72172bc0c28adb7e0d0  1997       Linkwood         Speyside
# 31031  678ee72172bc0c28adb7e0d1  2017      Cadenhead      Campbeltown
# 31032  678ee72272bc0c28adb7e0d2  2019        Barrell           Canada
# 31033  678ee72272bc0c28adb7e0d3  2019  Bruichladdich            Islay
# 31034  678ee72272bc0c28adb7e0d4  1990   Auchentoshan      Campbeltown
#
#       whiskey_country_of_origin  \
# 0                      Thailand
# 1                      Thailand
# 2                           USA
# 3                           USA
# 4                 United States
# ...                         ...
# 31030                  Scotland
# 31031                  Scotland
# 31032                    Canada
# 31033                  Scotland
# 31034                  Scotland
#
#                                             whiskey_name is_blend  \
# 0                                             100 Pipers     True
# 1                                             100 Pipers     True
# 2                                      225th Anniversary    False
# 3                                 1792 225th Anniversary    False
# 4                                        Bottled In Bond    False
# ...                                                  ...      ...
# 31030                             Linkwood 18y c1997 TEM    False
# 31031                   Campbeltown Living Cask 29/12/17     True
# 31032  Single Barrel Rye 13 Year Canadian (Alberta) 6...    False
# 31033                              Elements of Islay Br7    False
# 31034                         Auchentoshan 17 (Cask 190)    False
#
#                                              age whiskey_type  \
# 0                                            N/A        Blend
# 1                                            N/A        Blend
# 2      NAS but the bottle says 'nearly a decade'      Bourbon
# 3                                             10      Bourbon
# 4                             NAS but at least 4      Bourbon
# ...                                          ...          ...
# 31030                                         18       Scotch
# 31031                                    2 years       Scotch
# 31032                                         13          Rye
# 31033                                         15       Scotch
# 31034                                   17 years       Scotch
#
#                                                nose_tags  \
# 0                          [alcohol, leather, sweetness]
# 1                          [alcohol, leather, sweetness]
# 2       [sweet brown sugar, dark cherries, baking spice]
# 3      [acetone, oaky wood, dried herbs, cigar leaf, ...
# 4                      [Rich caramel, oak, hint of heat]
# ...                                                  ...
# 31030  [Shy, Sweet grapes, Strawberries ‘n’ cream oat...
# 31031    [smoke, crisp malt, lemon, grape, honey, dates]
# 31032  [cool rye spice, butterscotch, honey, orange z...
# 31033   [stewed plums, raisins, coffee, toasted coconut]
# 31034      [Floral, Honey, Vanilla, Malt, Grassy, Mango]
#
#                                             palette_tags  \
# 0                                         [bland, woody]
# 1                                         [bland, woody]
# 2                      [cherry pie, excellent mouthfeel]
# 3      [wood, herbal flavors, spice, baking spices, o...
# 4                          [oak forward, caramel, spice]
# ...                                                  ...
# 31030  [Hershey’s strawberry syrup, Thick, Fruity swe...
# 31031  [sweet grapes, savory cocoa-tobacco notes, car...
# 31032  [hot, very sweet, dry oak, ginger beer, Juicy ...
# 31033            [molasses, cocoa powder, coffee, lemon]
# 31034  [Creamy, Grassy, Malt, Vanilla, Apple, Pepper,...
#
#                                              finish_tags  \
# 0                                       [short, alcohol]
# 1                                       [short, alcohol]
# 2          [shorter, hotter, medium length, medium heat]
# 3      [warming, short, wood, vanilla, dried herbs, t...
# 4                           [Medium length, sweet, oaky]
# ...                                                  ...
# 31030                   [Kind of short, One dimensional]
# 31031                             [pizza crust, caramel]
# 31032                    [warm, sweet, close to cloying]
# 31033                        [tonic water, cocoa powder]
# 31034      [Malt, Honey, Floral, Vanilla, Pepper, Apple]
#
#                                    uuid  rating            user
# 0      1497ef54838b47d7a34f4085720a33da      68     merlinblack
# 1      1497ef54838b47d7a34f4085720a33da      68     merlinblack
# 2      5bfcb7bf5f454473b2042da21a0055a8      80   scottmotorrad
# 3      29ec172373944280ad2c2d0158db2928      80     WildOscar66
# 4      bffcc71c3ad64363a899fcac1be0cb46      80   scottmotorrad
# ...                                 ...     ...             ...
# 31030  36c8c8e3ca1d497fad4eeb53a4db6173      84  xreekinghavocx
# 31031  7d48731dc1bc4c56a39f8ff4d7612a53      90  xreekinghavocx
# 31032  3005814542914bbf8895a1d8a597d530      83  xreekinghavocx
# 31033  52bf3e6154f4464685a8a15117a5ad4f      89  xreekinghavocx
# 31034  c0e4165324544715aee2d112a070c34f      82           devoz
#
# [31035 rows x 15 columns]

# %%
all_review_df.shape
# Out:
# (31035, 15)

# %%
whiskey_reviews_wclusters = pd.merge(all_review_df, whiskey_df, how='left', left_on='whiskey_name', right_on='name')

# %%
whiskey_reviews_wclusters
# Out:
#                             _id  year     distillery disillery_region  \
# 0      678ee1a072bc0c28adb7679a  2012        Unknown            Blend
# 1      678ee1a072bc0c28adb7679b  2012     100 Pipers            Blend
# 2      678ee1a072bc0c28adb7679c  2018           1792         Kentucky
# 3      678ee1a072bc0c28adb7679d  2017         Barton         Kentucky
# 4      678ee1a072bc0c28adb7679e  2018           1792         Kentucky
# ...                         ...   ...            ...              ...
# 31030  678ee72172bc0c28adb7e0d0  1997       Linkwood         Speyside
# 31031  678ee72172bc0c28adb7e0d1  2017      Cadenhead      Campbeltown
# 31032  678ee72272bc0c28adb7e0d2  2019        Barrell           Canada
# 31033  678ee72272bc0c28adb7e0d3  2019  Bruichladdich            Islay
# 31034  678ee72272bc0c28adb7e0d4  1990   Auchentoshan      Campbeltown
#
#       whiskey_country_of_origin  \
# 0                      Thailand
# 1                      Thailand
# 2                           USA
# 3                           USA
# 4                 United States
# ...                         ...
# 31030                  Scotland
# 31031                  Scotland
# 31032                    Canada
# 31033                  Scotland
# 31034                  Scotland
#
#                                             whiskey_name is_blend  \
# 0                                             100 Pipers     True
# 1                                             100 Pipers     True
# 2                                      225th Anniversary    False
# 3                                 1792 225th Anniversary    False
# 4                                        Bottled In Bond    False
# ...                                                  ...      ...
# 31030                             Linkwood 18y c1997 TEM    False
# 31031                   Campbeltown Living Cask 29/12/17     True
# 31032  Single Barrel Rye 13 Year Canadian (Alberta) 6...    False
# 31033                              Elements of Islay Br7    False
# 31034                         Auchentoshan 17 (Cask 190)    False
#
#                                              age whiskey_type  \
# 0                                            N/A        Blend
# 1                                            N/A        Blend
# 2      NAS but the bottle says 'nearly a decade'      Bourbon
# 3                                             10      Bourbon
# 4                             NAS but at least 4      Bourbon
# ...                                          ...          ...
# 31030                                         18       Scotch
# 31031                                    2 years       Scotch
# 31032                                         13          Rye
# 31033                                         15       Scotch
# 31034                                   17 years       Scotch
#
#                                                nose_tags  \
# 0                          [alcohol, leather, sweetness]
# 1                          [alcohol, leather, sweetness]
# 2       [sweet brown sugar, dark cherries, baking spice]
# 3      [acetone, oaky wood, dried herbs, cigar leaf, ...
# 4                      [Rich caramel, oak, hint of heat]
# ...                                                  ...
# 31030  [Shy, Sweet grapes, Strawberries ‘n’ cream oat...
# 31031    [smoke, crisp malt, lemon, grape, honey, dates]
# 31032  [cool rye spice, butterscotch, honey, orange z...
# 31033   [stewed plums, raisins, coffee, toasted coconut]
# 31034      [Floral, Honey, Vanilla, Malt, Grassy, Mango]
#
#                                             palette_tags  \
# 0                                         [bland, woody]
# 1                                         [bland, woody]
# 2                      [cherry pie, excellent mouthfeel]
# 3      [wood, herbal flavors, spice, baking spices, o...
# 4                          [oak forward, caramel, spice]
# ...                                                  ...
# 31030  [Hershey’s strawberry syrup, Thick, Fruity swe...
# 31031  [sweet grapes, savory cocoa-tobacco notes, car...
# 31032  [hot, very sweet, dry oak, ginger beer, Juicy ...
# 31033            [molasses, cocoa powder, coffee, lemon]
# 31034  [Creamy, Grassy, Malt, Vanilla, Apple, Pepper,...
#
#                                              finish_tags  \
# 0                                       [short, alcohol]
# 1                                       [short, alcohol]
# 2          [shorter, hotter, medium length, medium heat]
# 3      [warming, short, wood, vanilla, dried herbs, t...
# 4                           [Medium length, sweet, oaky]
# ...                                                  ...
# 31030                   [Kind of short, One dimensional]
# 31031                             [pizza crust, caramel]
# 31032                    [warm, sweet, close to cloying]
# 31033                        [tonic water, cocoa powder]
# 31034      [Malt, Honey, Floral, Vanilla, Pepper, Apple]
#
#                                    uuid  rating            user  \
# 0      1497ef54838b47d7a34f4085720a33da      68     merlinblack
# 1      1497ef54838b47d7a34f4085720a33da      68     merlinblack
# 2      5bfcb7bf5f454473b2042da21a0055a8      80   scottmotorrad
# 3      29ec172373944280ad2c2d0158db2928      80     WildOscar66
# 4      bffcc71c3ad64363a899fcac1be0cb46      80   scottmotorrad
# ...                                 ...     ...             ...
# 31030  36c8c8e3ca1d497fad4eeb53a4db6173      84  xreekinghavocx
# 31031  7d48731dc1bc4c56a39f8ff4d7612a53      90  xreekinghavocx
# 31032  3005814542914bbf8895a1d8a597d530      83  xreekinghavocx
# 31033  52bf3e6154f4464685a8a15117a5ad4f      89  xreekinghavocx
# 31034  c0e4165324544715aee2d112a070c34f      82           devoz
#
#                                                     name  cluster
# 0                                             100 Pipers      715
# 1                                             100 Pipers      715
# 2                                      225th Anniversary     5230
# 3                                 1792 225th Anniversary     5231
# 4                                        Bottled In Bond     1322
# ...                                                  ...      ...
# 31030                             Linkwood 18y c1997 TEM     1933
# 31031                   Campbeltown Living Cask 29/12/17     1519
# 31032  Single Barrel Rye 13 Year Canadian (Alberta) 6...     4066
# 31033                              Elements of Islay Br7     1338
# 31034                         Auchentoshan 17 (Cask 190)     3220
#
# [31035 rows x 17 columns]

# %%
whiskey_reviews_wclusters['aged_clusters'] = whiskey_reviews_wclusters.groupby(['age', 'cluster']).ngroup()

# %%
whiskey_reviews_wclusters
# Out:
#                             _id  year     distillery disillery_region  \
# 0      678ee1a072bc0c28adb7679a  2012        Unknown            Blend
# 1      678ee1a072bc0c28adb7679b  2012     100 Pipers            Blend
# 2      678ee1a072bc0c28adb7679c  2018           1792         Kentucky
# 3      678ee1a072bc0c28adb7679d  2017         Barton         Kentucky
# 4      678ee1a072bc0c28adb7679e  2018           1792         Kentucky
# ...                         ...   ...            ...              ...
# 31030  678ee72172bc0c28adb7e0d0  1997       Linkwood         Speyside
# 31031  678ee72172bc0c28adb7e0d1  2017      Cadenhead      Campbeltown
# 31032  678ee72272bc0c28adb7e0d2  2019        Barrell           Canada
# 31033  678ee72272bc0c28adb7e0d3  2019  Bruichladdich            Islay
# 31034  678ee72272bc0c28adb7e0d4  1990   Auchentoshan      Campbeltown
#
#       whiskey_country_of_origin  \
# 0                      Thailand
# 1                      Thailand
# 2                           USA
# 3                           USA
# 4                 United States
# ...                         ...
# 31030                  Scotland
# 31031                  Scotland
# 31032                    Canada
# 31033                  Scotland
# 31034                  Scotland
#
#                                             whiskey_name is_blend  \
# 0                                             100 Pipers     True
# 1                                             100 Pipers     True
# 2                                      225th Anniversary    False
# 3                                 1792 225th Anniversary    False
# 4                                        Bottled In Bond    False
# ...                                                  ...      ...
# 31030                             Linkwood 18y c1997 TEM    False
# 31031                   Campbeltown Living Cask 29/12/17     True
# 31032  Single Barrel Rye 13 Year Canadian (Alberta) 6...    False
# 31033                              Elements of Islay Br7    False
# 31034                         Auchentoshan 17 (Cask 190)    False
#
#                                              age whiskey_type  \
# 0                                            N/A        Blend
# 1                                            N/A        Blend
# 2      NAS but the bottle says 'nearly a decade'      Bourbon
# 3                                             10      Bourbon
# 4                             NAS but at least 4      Bourbon
# ...                                          ...          ...
# 31030                                         18       Scotch
# 31031                                    2 years       Scotch
# 31032                                         13          Rye
# 31033                                         15       Scotch
# 31034                                   17 years       Scotch
#
#                                                nose_tags  \
# 0                          [alcohol, leather, sweetness]
# 1                          [alcohol, leather, sweetness]
# 2       [sweet brown sugar, dark cherries, baking spice]
# 3      [acetone, oaky wood, dried herbs, cigar leaf, ...
# 4                      [Rich caramel, oak, hint of heat]
# ...                                                  ...
# 31030  [Shy, Sweet grapes, Strawberries ‘n’ cream oat...
# 31031    [smoke, crisp malt, lemon, grape, honey, dates]
# 31032  [cool rye spice, butterscotch, honey, orange z...
# 31033   [stewed plums, raisins, coffee, toasted coconut]
# 31034      [Floral, Honey, Vanilla, Malt, Grassy, Mango]
#
#                                             palette_tags  \
# 0                                         [bland, woody]
# 1                                         [bland, woody]
# 2                      [cherry pie, excellent mouthfeel]
# 3      [wood, herbal flavors, spice, baking spices, o...
# 4                          [oak forward, caramel, spice]
# ...                                                  ...
# 31030  [Hershey’s strawberry syrup, Thick, Fruity swe...
# 31031  [sweet grapes, savory cocoa-tobacco notes, car...
# 31032  [hot, very sweet, dry oak, ginger beer, Juicy ...
# 31033            [molasses, cocoa powder, coffee, lemon]
# 31034  [Creamy, Grassy, Malt, Vanilla, Apple, Pepper,...
#
#                                              finish_tags  \
# 0                                       [short, alcohol]
# 1                                       [short, alcohol]
# 2          [shorter, hotter, medium length, medium heat]
# 3      [warming, short, wood, vanilla, dried herbs, t...
# 4                           [Medium length, sweet, oaky]
# ...                                                  ...
# 31030                   [Kind of short, One dimensional]
# 31031                             [pizza crust, caramel]
# 31032                    [warm, sweet, close to cloying]
# 31033                        [tonic water, cocoa powder]
# 31034      [Malt, Honey, Floral, Vanilla, Pepper, Apple]
#
#                                    uuid  rating            user  \
# 0      1497ef54838b47d7a34f4085720a33da      68     merlinblack
# 1      1497ef54838b47d7a34f4085720a33da      68     merlinblack
# 2      5bfcb7bf5f454473b2042da21a0055a8      80   scottmotorrad
# 3      29ec172373944280ad2c2d0158db2928      80     WildOscar66
# 4      bffcc71c3ad64363a899fcac1be0cb46      80   scottmotorrad
# ...                                 ...     ...             ...
# 31030  36c8c8e3ca1d497fad4eeb53a4db6173      84  xreekinghavocx
# 31031  7d48731dc1bc4c56a39f8ff4d7612a53      90  xreekinghavocx
# 31032  3005814542914bbf8895a1d8a597d530      83  xreekinghavocx
# 31033  52bf3e6154f4464685a8a15117a5ad4f      89  xreekinghavocx
# 31034  c0e4165324544715aee2d112a070c34f      82           devoz
#
#                                                     name  cluster  \
# 0                                             100 Pipers      715
# 1                                             100 Pipers      715
# 2                                      225th Anniversary     5230
# 3                                 1792 225th Anniversary     5231
# 4                                        Bottled In Bond     1322
# ...                                                  ...      ...
# 31030                             Linkwood 18y c1997 TEM     1933
# 31031                   Campbeltown Living Cask 29/12/17     1519
# 31032  Single Barrel Rye 13 Year Canadian (Alberta) 6...     4066
# 31033                              Elements of Islay Br7     1338
# 31034                         Auchentoshan 17 (Cask 190)     3220
#
#        aged_clusters
# 0               8772
# 1               8772
# 2              11165
# 3                528
# 4              11162
# ...              ...
# 31030           3583
# 31031           4265
# 31032           1980
# 31033           2498
# 31034           3513
#
# [31035 rows x 18 columns]

# %%
whiskey_reviews_wclusters.aged_clusters.value_counts()
# Out:
# aged_clusters
# 1562     171
# 3023     171
# 146      144
# 1336     138
# 305      130
#         ...
# 3363       1
# 10298      1
# 509        1
# 5164       1
# 3513       1
# Name: count, Length: 12465, dtype: int64

# %%
whiskey_reviews_wclusters.query('aged_clusters == 8950')
# Out:
#                             _id  year      distillery disillery_region  \
# 19256  678ee50872bc0c28adb7b2d2  2013  Johnnie Walker         Scotland
# 19257  678ee50872bc0c28adb7b2d3  2017  Johnnie Walker         Scotland
# 19258  678ee50872bc0c28adb7b2d4  2018  Johnnie Walker            Blend
# 19259  678ee50872bc0c28adb7b2d5  2013  Johnnie Walker            Blend
# 19260  678ee50872bc0c28adb7b2d6  2013  Johnnie Walker         Scotland
# 19261  678ee50872bc0c28adb7b2d7  2014  Johnnie Walker         Scotland
# 19262  678ee50872bc0c28adb7b2d8  2014  Johnnie Walker         Scotland
# 19263  678ee50872bc0c28adb7b2d9  2013  Johnnie Walker            Blend
# 19264  678ee50872bc0c28adb7b2da  2014  Johnnie Walker            Blend
# 19265  678ee50872bc0c28adb7b2db  2016  Johnnie Walker            Blend
# 19266  678ee50872bc0c28adb7b2dc  2012  Johnnie Walker         Scotland
# 19267  678ee50872bc0c28adb7b2dd  2012  Johnnie Walker            Blend
# 19268  678ee50872bc0c28adb7b2de  2013  Johnnie Walker            Blend
# 19270  678ee50972bc0c28adb7b2e0  2012  Johnnie Walker            Blend
# 19271  678ee50972bc0c28adb7b2e1  2012  Johnnie Walker         Scotland
# 19272  678ee50972bc0c28adb7b2e2  2013  Johnnie Walker            Blend
# 19273  678ee50972bc0c28adb7b2e3  2012  Johnnie Walker            Blend
# 19274  678ee50972bc0c28adb7b2e4  2013  Johnnie Walker            Blend
# 19275  678ee50972bc0c28adb7b2e5  2012  Johnnie Walker            Blend
# 19276  678ee50972bc0c28adb7b2e6  2013  Johnnie Walker         Scotland
# 19277  678ee50972bc0c28adb7b2e7  2012  Johnnie Walker            Blend
# 19278  678ee50972bc0c28adb7b2e8  2013  Johnnie Walker            Blend
# 19279  678ee50972bc0c28adb7b2e9  2012  Johnnie Walker            Blend
# 19280  678ee50972bc0c28adb7b2ea  2013  Johnnie Walker            Blend
# 19282  678ee50972bc0c28adb7b2ec  2015  Johnnie Walker            Blend
# 19283  678ee50972bc0c28adb7b2ed  2014  Johnnie Walker            Blend
# 19285  678ee50972bc0c28adb7b2ef  2012  Johnnie Walker            Blend
# 19286  678ee50972bc0c28adb7b2f0  2013  Johnnie Walker            Blend
# 19287  678ee50972bc0c28adb7b2f1  2017  Johnnie Walker         Scotland
# 19288  678ee50972bc0c28adb7b2f2  2016  Johnnie Walker            Blend
# 19289  678ee50972bc0c28adb7b2f3  2013  Johnnie Walker            Blend
# 19290  678ee50972bc0c28adb7b2f4  2015  Johnnie Walker         Scotland
# 19291  678ee50972bc0c28adb7b2f5  2013  Johnnie Walker         Scotland
# 19292  678ee50a72bc0c28adb7b2f6  2013  Johnnie Walker         Scotland
# 19293  678ee50a72bc0c28adb7b2f7  2014  Johnnie Walker            Blend
# 19294  678ee50a72bc0c28adb7b2f8  2014  Johnnie Walker            Blend
# 19295  678ee50a72bc0c28adb7b2f9  2013  Johnnie Walker         Scotland
# 19296  678ee50a72bc0c28adb7b2fa  2013  Johnnie Walker            Blend
# 19297  678ee50a72bc0c28adb7b2fb  2012  Johnnie Walker            Blend
# 19298  678ee50a72bc0c28adb7b2fc  2013  Johnnie Walker            Blend
# 19299  678ee50a72bc0c28adb7b2fd  2013  Johnnie Walker            Blend
# 19300  678ee50a72bc0c28adb7b2fe  2017  Johnnie Walker         Scotland
# 19301  678ee50a72bc0c28adb7b2ff  2012  Johnnie Walker         Scotland
# 19302  678ee50a72bc0c28adb7b300  2013  Johnnie Walker            Blend
# 19303  678ee50a72bc0c28adb7b301  2015  Johnnie Walker            Blend
# 19304  678ee50a72bc0c28adb7b302  2015  Johnnie Walker            Blend
# 19305  678ee50a72bc0c28adb7b303  2013  Johnnie Walker            Blend
# 19306  678ee50a72bc0c28adb7b304  2013  Johnnie Walker            Blend
# 19307  678ee50a72bc0c28adb7b305  2013  Johnnie Walker            Blend
# 19308  678ee50a72bc0c28adb7b306  2012  Johnnie Walker            Blend
# 19310  678ee50a72bc0c28adb7b308  2018  Johnnie Walker            Blend
# 19312  678ee50a72bc0c28adb7b30a  2017  Johnnie Walker            Blend
# 19315  678ee50b72bc0c28adb7b30d  1980  Johnnie Walker            Blend
#
#       whiskey_country_of_origin whiskey_name is_blend  age    whiskey_type  \
# 19256                  Scotland    Red Label     True  N/A          Scotch
# 19257                  Scotland    Red Label     True  N/A          Scotch
# 19258                  Scotland    Red Label     True  N/A          Scotch
# 19259                  Scotland    Red Label     True  N/A          Scotch
# 19260                  Scotland    Red Label     True  N/A           Blend
# 19261                  Scotland    Red Label     True  N/A           Blend
# 19262                  Scotland    Red Label     True  N/A          Scotch
# 19263                  Scotland    Red Label     True  N/A          Scotch
# 19264                  Scotland    Red Label     True  N/A          Scotch
# 19265                  Scotland    Red Label     True  N/A          Scotch
# 19266                  Scotland    Red Label     True  N/A          Scotch
# 19267                  Scotland    Red Label     True  N/A          Scotch
# 19268                  Scotland    Red Label     True  N/A          Scotch
# 19270                  Scotland    Red Label     True  N/A          Scotch
# 19271                  Scotland    Red Label     True  N/A           Blend
# 19272                  Scotland    Red Label     True  N/A          Scotch
# 19273                  Scotland    Red Label     True  N/A          Scotch
# 19274                  Scotland    Red Label     True  N/A          Scotch
# 19275                  Scotland    Red Label     True  N/A          Scotch
# 19276                  Scotland    Red Label     True  N/A          Scotch
# 19277                  Scotland    Red Label     True  N/A          Scotch
# 19278                  Scotland    Red Label     True  N/A          Scotch
# 19279                  Scotland    Red Label     True  N/A          Scotch
# 19280                  Scotland    Red Label     True  N/A          Scotch
# 19282                  Scotland    Red Label     True  N/A  Blended Scotch
# 19283                  Scotland    Red Label     True  N/A          Scotch
# 19285                  Scotland    Red Label     True  N/A          Scotch
# 19286                  Scotland    Red Label     True  N/A          Scotch
# 19287                  Scotland    Red Label     True  N/A          Scotch
# 19288                  Scotland    Red Label     True  N/A          Scotch
# 19289                  Scotland    Red Label     True  N/A          Scotch
# 19290                  Scotland    Red Label     True  N/A          Scotch
# 19291                  Scotland    Red Label     True  N/A          Scotch
# 19292                  Scotland    Red Label     True  N/A  Blended Scotch
# 19293                  Scotland    Red Label     True  N/A          Scotch
# 19294                  Scotland    Red Label     True  N/A          Scotch
# 19295                  Scotland    Red Label     True  N/A          Scotch
# 19296                  Scotland    Red Label     True  N/A          Scotch
# 19297                  Scotland    Red Label     True  N/A          Scotch
# 19298                  Scotland    Red Label     True  N/A          Scotch
# 19299                  Scotland    Red Label     True  N/A          Scotch
# 19300                  Scotland    Red Label     True  N/A          Scotch
# 19301                  Scotland    Red Label     True  N/A          Scotch
# 19302                  Scotland    Red Label     True  N/A          Scotch
# 19303                  Scotland    Red Label     True  N/A          Scotch
# 19304                  Scotland    Red Label     True  N/A          Scotch
# 19305                  Scotland    Red Label     True  N/A          Scotch
# 19306                  Scotland    Red Label     True  N/A          Scotch
# 19307                  Scotland    Red Label     True  N/A          Scotch
# 19308                  Scotland    Red Label     True  N/A          Scotch
# 19310                  Scotland    Red Label     True  N/A          Scotch
# 19312                  Scotland    Red Label     True  N/A          Scotch
# 19315                  Scotland    Red Label     True  N/A          Scotch
#
#                                                nose_tags  \
# 19256  [Caramel, Burnt marshmallows, Wheat, Barley, E...
# 19257                                                 []
# 19258        [Caramel, faint smoke, sea breeze, plastic]
# 19259  [Light fruit, grainy, rubbing alcohol, sweet h...
# 19260  [Denatured alcohol, unleaded gasoline, Concent...
# 19261   [Weak, Light caramel sweetness, apples, alcohol]
# 19262       [Acetone, Nail Polish, Honey, Peanut Butter]
# 19263  [Light fruit, grainy, rubbing alcohol, sweet h...
# 19264  [Peat, Smoke, Diesel, Artificial sweetener, Mo...
# 19265                                                 []
# 19266                             [Poison, butterscotch]
# 19267  [floral vinegar, apricots, vanilla ice, artifi...
# 19268                 [harsh alcohol, peppermint, chalk]
# 19270  [Vanilla, Honey, Cake batter, Spice cake, Swee...
# 19271                                                 []
# 19272  [Light fruit, grainy, rubbing alcohol, sweet h...
# 19273               [peat, smoky, brine, salty, bonfire]
# 19274  [Light fruit, grainy, rubbing alcohol, sweet h...
# 19275                                                 []
# 19276  [Sweet Grain, Smoke, Vanilla, Peat, Caramel, S...
# 19277                 [alcohol, sugar, vanilla, caramel]
# 19278                            [Harsh, torture, smell]
# 19279                    [Alcohol, Sugar, Salt, Caramel]
# 19280  [Light fruit, grainy, rubbing alcohol, sweet h...
# 19282           [Acetone, alcohol, malt, grain, vanilla]
# 19283                                                 []
# 19285                                                 []
# 19286  [Light fruit, grainy, rubbing alcohol, sweet h...
# 19287                                                 []
# 19288                                                 []
# 19289  [Light fruit, grainy, rubbing alcohol, sweet h...
# 19290                                                 []
# 19291                                                 []
# 19292               [Isopropyl alcohol, honey, cinnamon]
# 19293  [faint sour apple, acrid burning, bubblegum, s...
# 19294  [Sweet grain, slight earth, vanilla, acetone, ...
# 19295  [alcoholic, earthy, grass, bark, sweetness, ho...
# 19296  [Light fruit, grainy, rubbing alcohol, sweet h...
# 19297  [Grain, Plastic, Smoke, Peat, Green Apples, Ha...
# 19298  [Light fruit, grainy, rubbing alcohol, sweet h...
# 19299  [vanilla, dried figs, intense sweetness, rubbi...
# 19300                     [Alcohol, Grain, Pear, Toffee]
# 19301     [sweet, vanilla, almonds, gum, paper, thinner]
# 19302  [Light fruit, grainy, rubbing alcohol, sweet h...
# 19303                                                 []
# 19304             [Moldy peaches, alcohol, wheat, grass]
# 19305  [Light fruit, grainy, rubbing alcohol, sweet h...
# 19306                             [Ethanol, sweet grain]
# 19307  [Light fruit, grainy, rubbing alcohol, sweet h...
# 19308                  [Green apple, gravy, nail polish]
# 19310                                                 []
# 19312                                         [band-aid]
# 19315  [must, gravy, iodine, smoked herring, lint, li...
#
#                                             palette_tags  \
# 19256  [Toffee, Slight honey, Earthy, Vanilla, Woody,...
# 19257                                                 []
# 19258            [Watery, caramel, light smoke, plastic]
# 19259  [Vanilla, green fruits, woody, soapy, astringent]
# 19260  [Grass, cheap vodka, Chemicals, corn, shitty m...
# 19261          [Sweet cream, Bitter grain alcohol, corn]
# 19262                     [Nail Polish, Vanilla, Watery]
# 19263  [Vanilla, green fruits, woody, soapy, astringent]
# 19264                            [Alcohol, Rough, Moldy]
# 19265                                                 []
# 19266          [Smoke, poison, pine needles, moldy wood]
# 19267  [particle board in cheap office furniture, som...
# 19268       [pear, licorice, malt, kerosene, peat smoke]
# 19270  [Waterlogged cardboard, Sanitizer water, Grain...
# 19271                                                 []
# 19272  [Vanilla, green fruits, woody, soapy, astringent]
# 19273               [thick, oily, salty, campfire smoke]
# 19274  [Vanilla, green fruits, woody, soapy, astringent]
# 19275                                                 []
# 19276  [Cereal Grains, Peat, Light Barrel Char, Honey...
# 19277               [sugar, alcohol, fruit, apple, pear]
# 19278                             [sweet, weak, vanilla]
# 19279                         [Alcohol, Wood, Sweetness]
# 19280  [Vanilla, green fruits, woody, soapy, astringent]
# 19282            [Alcohol, sugar, oak, peanuts, caramel]
# 19283                                                 []
# 19285                                                 []
# 19286  [Vanilla, green fruits, woody, soapy, astringent]
# 19287                                                 []
# 19288                                                 []
# 19289  [Vanilla, green fruits, woody, soapy, astringent]
# 19290                                                 []
# 19291                                                 []
# 19292                    [Vanilla, apple, harsh alcohol]
# 19293  [watery, bubblegum, rubbing alcohol, freshly m...
# 19294  [rough booze hit, sweet grain, wood char, ligh...
# 19295        [sweet, candied dried fruit, cringe-worthy]
# 19296  [Vanilla, green fruits, woody, soapy, astringent]
# 19297  [Thin, Bitter, Peppery, Plastic Rope, Grain, S...
# 19298  [Vanilla, green fruits, woody, soapy, astringent]
# 19299  [burnt raisins, figs, vanilla, malty, bitterness]
# 19300  [Generic whiskey flavor, Smoke, Alcohol, Cardb...
# 19301  [bile, sugary grain, nail polish remover, sour...
# 19302  [Vanilla, green fruits, woody, soapy, astringent]
# 19303                                                 []
# 19304               [Corn, burning plastic, malt, lemon]
# 19305  [Vanilla, green fruits, woody, soapy, astringent]
# 19306          [Grain whisky, white pepper, faint honey]
# 19307  [Vanilla, green fruits, woody, soapy, astringent]
# 19308      [Stewed apples, oatmeal, malty grain alcohol]
# 19310                                                 []
# 19312                                       [chewy, gum]
# 19315  [clover honey, dirt, grass, moss, savory onion...
#
#                                              finish_tags  \
# 19256  [Quick finish, Little sweetness, Very smooth, ...
# 19257                                                 []
# 19258        [Sweet, drying, bitter, solvent aftertaste]
# 19259                                   [Vanilla, grain]
# 19260                           [Dry, bitter, molesting]
# 19261               [Alcohol burn, smoke, not much else]
# 19262                [Harsh, Drying, Nail Polish, Funky]
# 19263                                   [Vanilla, grain]
# 19264                           [Sickly sweet cardboard]
# 19265                                                 []
# 19266                [Acidic burn, lingering bitterness]
# 19267  [grain, hints of ginger and potato in the skin...
# 19268                            [copper, not much else]
# 19270                    [Dry, Awkward sugar, Cardboard]
# 19271                                                 []
# 19272                                   [Vanilla, grain]
# 19273                     [dry, sherry spice, lingering]
# 19274                                   [Vanilla, grain]
# 19275                                                 []
# 19276          [Sweet Grains, Tinny/Metallic, Raw Sugar]
# 19277                   [hard bite, heavy alcohol sting]
# 19278                 [quick, assault, rough, sweetness]
# 19279                                   [Alcohol, Sugar]
# 19280                                   [Vanilla, grain]
# 19282  [Alcohol, medicine, salt water, grain, sugar, ...
# 19283                                                 []
# 19285                                                 []
# 19286                                   [Vanilla, grain]
# 19287                                                 []
# 19288                                                 []
# 19289                                   [Vanilla, grain]
# 19290                                                 []
# 19291                                                 []
# 19292         [unidentifiable sweetness, toasted grains]
# 19293            [short, alcohol burn, hot scotch water]
# 19294                              [Booze, faint spices]
# 19295             [dry, lacking, sweetness, quick to go]
# 19296                                   [Vanilla, grain]
# 19297   [Quick Fade, Spice, Red Pepper, Acetone, Fennel]
# 19298                                   [Vanilla, grain]
# 19299     [rapidly fading sweetness, lasting bitterness]
# 19300        [Medicinal, Bitter root, Slightly metallic]
# 19301                                  [stingy, treacle]
# 19302                                   [Vanilla, grain]
# 19303                                                 []
# 19304        [Smoke, burnt dust, toast, cheap marmalade]
# 19305                                   [Vanilla, grain]
# 19306                                     [WHAT FINISH?]
# 19307                                   [Vanilla, grain]
# 19308     [Quit the race halfway, Holland lager lingers]
# 19310                                                 []
# 19312                                                 []
# 19315       [smokey black pepper, milk chocolate, honey]
#
#                                    uuid  rating                 user  \
# 19256  3e661e5bafbc43faa97809a79db4c90d      86       luckyaussiebob
# 19257  3f2a343bdc81401483ecbd37b3172519      52              SPG2469
# 19258  2d6a68ecc22c45fba454c4ef010af729      65   unbreakablesausage
# 19259  e3be8cda7727415fada3476ad1c36bba      50           airpower47
# 19260  ce3c23053a0a43e896871bfd0a104add      10             Allumina
# 19261  7c6c8d98aa3846219dd420edf0955060      50              Allurex
# 19262  406d2a4464d14bfe962caa47bbb3f860      35     ArdbegYourPardon
# 19263  375dec20d38e415ab0fadcea6419cc92      45               ayedfy
# 19264  30b0a9fb74f348cfb7167717bd807506      40      barbecue_scotch
# 19265  ddcc8c41a58e4b98a17138fdc2a3d7df      65              bbeng89
# 19266  c54c1ed7c42043408e60a12bf48187e1      40           Blenderate
# 19267  001efb71ab624ece91ea72e46d834264      68          cake_my_day
# 19268  1690987d823b4a4d895a8afe82b207cb      71        ChainChompsky
# 19270  c131cf594dde482dbc942074f74e904d      30         cpelletier89
# 19271  0e8ced99e6574674972e32b5b9f17eed      57       CreamSpinachYo
# 19272  d74ad727442a4ca895cf8123f79107bc      45            DDukedesu
# 19273  bbedf0a047bc42798ef0f77581036f46      70        Disco_Biscuit
# 19274  20b5d4bb34c04c2982f5a6ff62a93b18      65               Dworgi
# 19275  c0b540251cdd4c70a001ae3ff51f6078      65              esajz24
# 19276  18f72ad98b3f4f3d95d15b433d9896e3      68              esajz24
# 19277  ff518e3c29f74ec9811691b6e9cbd8ff      69         falingodingo
# 19278  ad351a1b170645fa83ac9e7107e13072      30              gaxkang
# 19279  c7a2cd73f3654c00a3bac0928398c100      60              gimpwiz
# 19280  e3b2fee770874c46b257fd7f48244063      54            hailchaos
# 19282  d2f3d6d0699c42beacd9187dea24f7be      35               JCappy
# 19283  92dd02e7d1f54f24bbd72f05302ba743      25         Joan_de_Gant
# 19285  83df20c8341341cab2be88749e2deca4      30           jonker1541
# 19286  693a6e0dbb394e5690f596afccf95020      33              jooni81
# 19287  76699cc4452d4c2ba2fcd5d4319a7426      55             MajorHop
# 19288  d89f64cc16ce496695acc85e17e437e0      10        mister_damage
# 19289  5d011b13f3e84361bb2bb86c139c5744      63     mountaingoatinSD
# 19290  c8973c99298846d29d05c6c6b6f5fc59      47            muaddib99
# 19291  4c56b890b1d345b4b28171fe02c3dc1b      20                mudze
# 19292  9e20ac57f9114d7bba925870a11ed423      60             NobleArc
# 19293  8cdc014d17ce437885b1fa321f8d21a5      50          OfficerJerd
# 19294  1775e8d40168411781b01a1fe355c6b7      65             radiozip
# 19295  c6ead346c4d248c98003460824c0f29d      60              rmill3r
# 19296  297c943545874a5c972c75e2a4f64274      38          rocketsmurf
# 19297  b8b02689adda4f1dbe86b000250f32d6      42          rockindaddy
# 19298  842d378732d2449a89695498c7ac1088      60                shigy
# 19299  930550d647904562a10af677cff795e8      55            superyeti
# 19300  458bb001aa0e4cfe8861be204a1c78ca      45             tambrico
# 19301  5050ba0035e545a1b15184f6b8bdf3f0      28              Texacer
# 19302  8c3ea7c555244ebeaaac1ddb7dc0cb84      65           thatguy142
# 19303  dc94dc8b8f474db79154cc43242e829d      60            tintin777
# 19304  c7a8081dddff46c4b033d025df5d3507      49             TOModera
# 19305  c3c6809b3b87429a8908d5fe8c2a531d      65               Trexid
# 19306  ed20a955643240edbbd6c60d10de6e4c      50           UncleTobys
# 19307  758692f88c754a769e5233429e18888b      65            ziggy1283
# 19308  87ae087b5d814f1dac9eb3af6c30b4c1      71           Zillah1985
# 19310  6767d22480c84baf8c0669bca2ff4732      53       Unclimbability
# 19312  c2a5902542454b45992e992a5a929076      60  bloom_wellick_group
# 19315  8eea692a96bb45a49aba430fdc7b2312      77           Zillah1985
#
#             name  cluster  aged_clusters
# 19256  Red Label     1187           8950
# 19257  Red Label     1187           8950
# 19258  Red Label     1187           8950
# 19259  Red Label     1187           8950
# 19260  Red Label     1187           8950
# 19261  Red Label     1187           8950
# 19262  Red Label     1187           8950
# 19263  Red Label     1187           8950
# 19264  Red Label     1187           8950
# 19265  Red Label     1187           8950
# 19266  Red Label     1187           8950
# 19267  Red Label     1187           8950
# 19268  Red Label     1187           8950
# 19270  Red Label     1187           8950
# 19271  Red Label     1187           8950
# 19272  Red Label     1187           8950
# 19273  Red Label     1187           8950
# 19274  Red Label     1187           8950
# 19275  Red Label     1187           8950
# 19276  Red Label     1187           8950
# 19277  Red Label     1187           8950
# 19278  Red Label     1187           8950
# 19279  Red Label     1187           8950
# 19280  Red Label     1187           8950
# 19282  Red Label     1187           8950
# 19283  Red Label     1187           8950
# 19285  Red Label     1187           8950
# 19286  Red Label     1187           8950
# 19287  Red Label     1187           8950
# 19288  Red Label     1187           8950
# 19289  Red Label     1187           8950
# 19290  Red Label     1187           8950
# 19291  Red Label     1187           8950
# 19292  Red Label     1187           8950
# 19293  Red Label     1187           8950
# 19294  Red Label     1187           8950
# 19295  Red Label     1187           8950
# 19296  Red Label     1187           8950
# 19297  Red Label     1187           8950
# 19298  Red Label     1187           8950
# 19299  Red Label     1187           8950
# 19300  Red Label     1187           8950
# 19301  Red Label     1187           8950
# 19302  Red Label     1187           8950
# 19303  Red Label     1187           8950
# 19304  Red Label     1187           8950
# 19305  Red Label     1187           8950
# 19306  Red Label     1187           8950
# 19307  Red Label     1187           8950
# 19308  Red Label     1187           8950
# 19310  Red Label     1187           8950
# 19312  Red Label     1187           8950
# 19315  Red Label     1187           8950

# %%
whiskey_reviews_wclusters.aged_clusters.nunique()
# Out:
# 12465

# %%
tasting_notes = whiskey_reviews_wclusters.query('aged_clusters == 8950')['nose_tags']

# %%
import numpy as np
import pandas as pd
from sentence_transformers import SentenceTransformer
from sklearn.cluster import DBSCAN
from collections import Counter
from scipy.spatial.distance import cdist

# %%
def get_representative_word(cluster_words, model):
    """Selects the most central word in a cluster based on cosine similarity."""
    words, _ = zip(*cluster_words)
    word_embeddings = np.array([model.encode(word) for word in words])
    centroid = np.mean(word_embeddings, axis=0)
    distances = cdist([centroid], word_embeddings, metric="cosine")[0]
    return words[np.argmin(distances)]  # Select the word closest to centroid


def generate_tasting_themes(tasting_notes=None, threshold=0.45, model=None):
    '''
    Function takes a list of tasting note keywords, embeds them together, clusters and aggregates, and selects up to the 10 most frequent terms.
    '''

    #print('Running Code')
    all_keywords = []
    for note in tasting_notes:
        all_keywords.extend(note)

    # Remove duplicates and keep unique keywords
    unique_keywords = list(set(all_keywords))

    if len(unique_keywords) == 0:
        return []
    elif len(unique_keywords) <= 10:
        return unique_keywords
    else:
        #Create Embeddings
        embeddings = model.encode(unique_keywords)

        # DBSCAN
        dbscan = DBSCAN(eps=threshold, min_samples=2, metric="cosine")  # Adjust `eps` as needed
        labels = dbscan.fit_predict(embeddings)

        cluster_map = {unique_keywords[i]: labels[i] for i in range(len(unique_keywords))}
        keyword_counts = Counter(all_keywords)
        # Group keywords by clusters
        cluster_groups = {}
        defaults = []
        # Need to figure out what happens here if DBSCAN doesn't have clusters
        for keyword, cluster in cluster_map.items():
            if cluster == -1:  # Ignore noise points
                defaults.append(keyword)
            if cluster not in cluster_groups:
                cluster_groups[cluster] = []
            cluster_groups[cluster].append((keyword, keyword_counts[keyword]))

        # Step 5: Select Top 10 Densest Clusters
        sorted_clusters = sorted(cluster_groups.items(), key=lambda x: len(x[1]), reverse=True)[:10]

        top_themes = [get_representative_word(words, model) for _, words in sorted_clusters]

        if (len(top_themes) < 10) and (len(defaults) > 0):
            return top_themes + defaults[0:(11 - len(top_themes))]
        return top_themes

# %%
embedding_model=SentenceTransformer('all-MiniLM-L6-v2')

nose_notes = whiskey_reviews_wclusters.query('aged_clusters == 8950')['nose_tags']
palette_notes = whiskey_reviews_wclusters.query('aged_clusters == 8950')['palette_tags']
finish_notes = whiskey_reviews_wclusters.query('aged_clusters == 8950')['finish_tags']

# %%
nose_themes = generate_tasting_themes(nose_notes, threshold=0.45, model=embedding_model)
print(nose_themes)
# Out:
# Running Code
# ['sweetness', 'alcohol', 'grass', 'Spice cake', 'vanilla', 'Earthy', 'bubblegum', 'Peat', 'plastic', 'acetone']

# %%
palette_themes = generate_tasting_themes(palette_notes, threshold=0.45, model=embedding_model)
print(palette_themes)
# Out:
# Running Code
# ['sweet grain', 'Wood', 'white pepper', 'peat smoke', 'Grass', 'licorice', 'woody', 'Chemicals', 'Good steak', 'vanilla']

# %%
finish_themes = generate_tasting_themes(finish_notes, threshold=0.45, model=embedding_model)
print(finish_themes)
# Out:
# Running Code
# ['sweetness', 'Alcohol burn', 'Spice', 'lingering bitterness', 'Drying', 'Oily but very slick', 'Smoke', 'Sickly sweet cardboard', 'Medicinal', 'Slightly metallic']

# %% [markdown]
# ### Now We Need to Apply This to Every Whiskey

# %%
from pydantic import BaseModel, Field
whiskeys_by_id = {}

### Pydantic Object
class WhiskeyBase(BaseModel):
    whiskey_name: str = Field(..., description="The name of the whiskey without distiller or age")
    nose_tags: list[str] = Field(..., description='Keywords describing the nose/smell of the whiskey from the provided review')
    palette_tags: list[str] = Field(..., description='Keywords describing the nose/smell of the whiskey from the provided review')
    finish_tags: list[str] = Field(..., description="Keywords describing the finish of the whiskey")

for idx, grp in whiskey_reviews_wclusters.head(1000).groupby('aged_clusters'):

    nose_themes = generate_tasting_themes(grp.nose_tags, threshold=0.45, model=embedding_model)
    palette_themes = generate_tasting_themes(grp.palette_tags, threshold=0.45, model=embedding_model)
    finish_themes = generate_tasting_themes(grp.finish_tags, threshold=0.45, model=embedding_model)

    whiskey = WhiskeyBase(whiskey_name=str(idx), nose_tags=nose_themes, palette_tags=palette_themes, finish_tags=finish_themes)

    whiskeys_by_id[idx] = whiskey

# %%
pd.DataFrame(whiskeys_by_id).T
# Out:
#                            0  \
# 121      (whiskey_name, 121)
# 528      (whiskey_name, 528)
# 813      (whiskey_name, 813)
# 4242    (whiskey_name, 4242)
# 4278    (whiskey_name, 4278)
# 6669    (whiskey_name, 6669)
# 6671    (whiskey_name, 6671)
# 6682    (whiskey_name, 6682)
# 6697    (whiskey_name, 6697)
# 7185    (whiskey_name, 7185)
# 7253    (whiskey_name, 7253)
# 7330    (whiskey_name, 7330)
# 7638    (whiskey_name, 7638)
# 7898    (whiskey_name, 7898)
# 7925    (whiskey_name, 7925)
# 7939    (whiskey_name, 7939)
# 8712    (whiskey_name, 8712)
# 8713    (whiskey_name, 8713)
# 8772    (whiskey_name, 8772)
# 8895    (whiskey_name, 8895)
# 9348    (whiskey_name, 9348)
# 9349    (whiskey_name, 9349)
# 9579    (whiskey_name, 9579)
# 9580    (whiskey_name, 9580)
# 9581    (whiskey_name, 9581)
# 9582    (whiskey_name, 9582)
# 9584    (whiskey_name, 9584)
# 9596    (whiskey_name, 9596)
# 9597    (whiskey_name, 9597)
# 9814    (whiskey_name, 9814)
# 9935    (whiskey_name, 9935)
# 10097  (whiskey_name, 10097)
# 10269  (whiskey_name, 10269)
# 10473  (whiskey_name, 10473)
# 10542  (whiskey_name, 10542)
# 10844  (whiskey_name, 10844)
# 10845  (whiskey_name, 10845)
# 10846  (whiskey_name, 10846)
# 10861  (whiskey_name, 10861)
# 10868  (whiskey_name, 10868)
# 11035  (whiskey_name, 11035)
# 11036  (whiskey_name, 11036)
# 11106  (whiskey_name, 11106)
# 11108  (whiskey_name, 11108)
# 11157  (whiskey_name, 11157)
# 11162  (whiskey_name, 11162)
# 11165  (whiskey_name, 11165)
# 11264  (whiskey_name, 11264)
# 11293  (whiskey_name, 11293)
# 11321  (whiskey_name, 11321)
# 11398  (whiskey_name, 11398)
# 11427  (whiskey_name, 11427)
# 11518  (whiskey_name, 11518)
# 11568  (whiskey_name, 11568)
# 11794  (whiskey_name, 11794)
# 11816  (whiskey_name, 11816)
# 12051  (whiskey_name, 12051)
# 12135  (whiskey_name, 12135)
# 12329  (whiskey_name, 12329)
#
#                                                        1  \
# 121    (nose_tags, [Oak, Caramel, Brown Sugar, Strong...
# 528    (nose_tags, [dried herbs, cigar leaf, oaky woo...
# 813    (nose_tags, [rye spice, vanilla, berries, hone...
# 4242   (nose_tags, [muted, orange peel, raspberries, ...
# 4278   (nose_tags, [Red grapes, Brioche, Strawberry j...
# 6669   (nose_tags, [orange peel, brown sugar, toffee,...
# 6671   (nose_tags, [maple syrup, perfume notes, whipp...
# 6682                     (nose_tags, [Acetone, Bananas])
# 6697   (nose_tags, [Cherries, acetone, herbal, vanill...
# 7185   (nose_tags, [cherry, grape hard candies, maple...
# 7253   (nose_tags, [coconut, toasty oak, cloves, vani...
# 7330   (nose_tags, [oak char, burnt butter, Roasted c...
# 7638   (nose_tags, [chocolate, old wood, rye spices, ...
# 7898   (nose_tags, [dark fruits, tannic bitter tea, W...
# 7925   (nose_tags, [Strawberries, cherries, spicy not...
# 7939   (nose_tags, [french vanilla, young oak, cherry...
# 8712   (nose_tags, [Red Fruit, Rubbing Alcohol, White...
# 8713   (nose_tags, [cream, Sweet vanilla caramels, Oa...
# 8772          (nose_tags, [sweetness, leather, alcohol])
# 8895   (nose_tags, [caramel, plums, artificial plasti...
# 9348   (nose_tags, [caramel, Muted vanilla, cherry so...
# 9349   (nose_tags, [clove, fresh lumber, orange, ligh...
# 9579   (nose_tags, [Cinnamon, Oak, Orange, Herbal, Et...
# 9580   (nose_tags, [ripe white peach, mild rye spice,...
# 9581   (nose_tags, [Butter, vanilla/oak, white peach,...
# 9582   (nose_tags, [sweet rye, caramel, corn heavy sw...
# 9584                                     (nose_tags, [])
# 9596   (nose_tags, [alcohol, bananas, Sweet corn, oak...
# 9597                                     (nose_tags, [])
# 9814   (nose_tags, [pineapple, charcoal, grainy spice...
# 9935   (nose_tags, [cola, rye spice, sweet vanilla, c...
# 10097  (nose_tags, [Plum, sweet corn, almost no alcoh...
# 10269  (nose_tags, [brown sugar, vanilla, custard, ca...
# 10473  (nose_tags, [Fake vanilla, Low quality chocola...
# 10542  (nose_tags, [lime, Oak, rye spice, fruity, che...
# 10844  (nose_tags, [walnut, nutty, candied cinnamon, ...
# 10845  (nose_tags, [leather, caramel, smokiness, must...
# 10846  (nose_tags, [mint, vanilla, black pepper, rich...
# 10861  (nose_tags, [oak, hints of spice, heat, sweet ...
# 10868  (nose_tags, [vanilla, citrus, baking spice, Sw...
# 11035  (nose_tags, [bubble gum, toasted marshmallow, ...
# 11036  (nose_tags, [Sweet jam, stewed fruits, caramel...
# 11106  (nose_tags, [vanilla, caramel, citrus, rich sw...
# 11108  (nose_tags, [vanilla, citrus, baking spice, Sw...
# 11157  (nose_tags, [cherry, sweet grapes, bananas, ca...
# 11162     (nose_tags, [oak, Rich caramel, hint of heat])
# 11165  (nose_tags, [dark cherries, baking spice, swee...
# 11264  (nose_tags, [vanilla, woody oak, tannic comple...
# 11293  (nose_tags, [ripe banana, caramel, young, swee...
# 11321  (nose_tags, [banana note, rye menthol spice, e...
# 11398  (nose_tags, [Cinnamon, Ethanol, Pecan, Banana,...
# 11427  (nose_tags, [brown sugar, juicy fruits, dusty ...
# 11518  (nose_tags, [vanilla, cinnamon, herbal, mango,...
# 11568  (nose_tags, [Very sweet, Hostess cherry fruit ...
# 11794  (nose_tags, [cereal, fruit sweet, cinnamon, nu...
# 11816  (nose_tags, [butter, grape sugar, toasted coco...
# 12051  (nose_tags, [vanilla, root beer, oak, Sweet or...
# 12135                                    (nose_tags, [])
# 12329                                    (nose_tags, [])
#
#                                                        2  \
# 121    (palette_tags, [Thick, black pepper, hint of b...
# 528    (palette_tags, [herbal flavors, oaky vanilla, ...
# 813    (palette_tags, [burnt sugar, vanilla, thick, o...
# 4242   (palette_tags, [black pepper, tannic, mild ent...
# 4278   (palette_tags, [Black tea, Berry flavors, Swee...
# 6669   (palette_tags, [cloves, spicy, young oak, toba...
# 6671   (palette_tags, [bitter, floral, apple juice, r...
# 6682   (palette_tags, [Coffee, Acetone, Oak, Caramel,...
# 6697   (palette_tags, [heavy toffee, granny smith app...
# 7185   (palette_tags, [moderately oily, tannin filled...
# 7253   (palette_tags, [bitter, dark chocolate, raspbe...
# 7330   (palette_tags, [black coffee, brown sugar, pep...
# 7638   (palette_tags, [chocolate, oak, orange zest, b...
# 7898   (palette_tags, [oak, darker tannic notes, swee...
# 7925   (palette_tags, [cherry concentrate, ripe cherr...
# 7939   (palette_tags, [fruit punch, vanilla frosted c...
# 8712   (palette_tags, [Red Fruit, Rubbing Alcohol, Po...
# 8713   (palette_tags, [pepper, light fruity sweetness...
# 8772                      (palette_tags, [woody, bland])
# 8895   (palette_tags, [caramel, alcohol burn, vanilla...
# 9348   (palette_tags, [smooth, chalky caramel sweetne...
# 9349   (palette_tags, [spicy, apple pie, oak, intense...
# 9579   (palette_tags, [Spice, Cinnamon, Oak, Hot, Sug...
# 9580   (palette_tags, [white peach, woody, saccharine...
# 9581   (palette_tags, [cherry, caramel, cola, cherry,...
# 9582   (palette_tags, [caramel, banana, toffee, young...
# 9584                                  (palette_tags, [])
# 9596   (palette_tags, [corn, mint, dry, thicker mouth...
# 9597                                  (palette_tags, [])
# 9814   (palette_tags, [cinnamon spice, tannic, vanill...
# 9935   (palette_tags, [rye spice, granny smith apple,...
# 10097  (palette_tags, [caramel, fruit, bitter wood, m...
# 10269  (palette_tags, [burnt sugar, orange peel, oaky...
# 10473  (palette_tags, [Light mouthfeel, Corn, Mealy a...
# 10542  (palette_tags, [cola, cherry tart, rye spice, ...
# 10844  (palette_tags, [corn, oaky astringency, oaky, ...
# 10845  (palette_tags, [hot, faint peaches, oak, peppe...
# 10846  (palette_tags, [vanilla, mint, spicy, black pe...
# 10861  (palette_tags, [more caramel, spice notes, mor...
# 10868  (palette_tags, [acetone, caramel, citrus, thin...
# 11035     (palette_tags, [bubble gum, heat, oak, spice])
# 11036  (palette_tags, [fruity, No bitterness, vanilla...
# 11106  (palette_tags, [citrus, bold sweet vanilla, hi...
# 11108  (palette_tags, [acetone, vanilla, caramel, oak...
# 11157  (palette_tags, [smooth, very sweet, easy drink...
# 11162      (palette_tags, [oak forward, caramel, spice])
# 11165  (palette_tags, [excellent mouthfeel, cherry pie])
# 11264          (palette_tags, [honey, sweet, rye spice])
# 11293  (palette_tags, [banana, tobacco, leathery, oak...
# 11321  (palette_tags, [banana, vanilla, caramel, spic...
# 11398  (palette_tags, [Spicy oak, Caramel, Pecan, Bro...
# 11427  (palette_tags, [Heavy oak, gingerbread, brown ...
# 11518  (palette_tags, [sweetness, herbal, hot, vanill...
# 11568  (palette_tags, [tart cherry, Caramel, wood cha...
# 11794  (palette_tags, [rye spice, spicy, pepper, citr...
# 11816  (palette_tags, [sour candy, sweet oak, nutty, ...
# 12051  (palette_tags, [banana, apple peel, fennel, or...
# 12135                                 (palette_tags, [])
# 12329                                 (palette_tags, [])
#
#                                                        3
# 121    (finish_tags, [Long, black pepper, Rye spice, ...
# 528    (finish_tags, [dried herbs, tobacco, warming, ...
# 813    (finish_tags, [rye spice, oak, creamy vanilla,...
# 4242   (finish_tags, [tart raspberries, mint, black p...
# 4278   (finish_tags, [Artificial strawberry, A little...
# 6669   (finish_tags, [rye notes, rich mouth-feel, int...
# 6671   (finish_tags, [young spirit, Bitter, rye forwa...
# 6682   (finish_tags, [Bitter, Harsh, Thin body, Unple...
# 6697       (finish_tags, [red-wine notes, Tannic, sour])
# 7185   (finish_tags, [orchard fruits, burnt spearmint...
# 7253         (finish_tags, [weak, dry, short, pleasant])
# 7330       (finish_tags, [Long, medium mouthfeel, oaky])
# 7638   (finish_tags, [spicy, wood, bitter oak, medium...
# 7898    (finish_tags, [not complex, tapers off, unique])
# 7925   (finish_tags, [slight harshness, bursting flav...
# 7939      (finish_tags, [dry, heat, spicy port profile])
# 8712   (finish_tags, [Maple Pancakes, Red Fruit, Rubb...
# 8713   (finish_tags, [rum, vanilla, Warm, Oak, bitter...
# 8772                     (finish_tags, [short, alcohol])
# 8895   (finish_tags, [peach, pepper, clove spice, cre...
# 9348   (finish_tags, [spicy, lightly bitter oak, astr...
# 9349   (finish_tags, [more clove, dry cinnamon bark, ...
# 9579                (finish_tags, [Dry, Oak, Chocolate])
# 9580   (finish_tags, [shorter, less complex, understa...
# 9581   (finish_tags, [Coconut, shorter, coffee, toast...
# 9582   (finish_tags, [Long, leathery, hot, caramel, p...
# 9584                                   (finish_tags, [])
# 9596   (finish_tags, [wheat, corn, tingle, medium fin...
# 9597                                   (finish_tags, [])
# 9814   (finish_tags, [creamy, slow burn, thin, linger...
# 9935            (finish_tags, [cinnamon, sweet vanilla])
# 10097  (finish_tags, [cinnamon, medium length, dried ...
# 10269   (finish_tags, [long, warm, woody banana, spicy])
# 10473  (finish_tags, [Cinnamon, Low quality chocolate...
# 10542  (finish_tags, [pepper, medium length, tobacco,...
# 10844                   (finish_tags, [bourbon-y, warm])
# 10845  (finish_tags, [oak, long-lasting warmth, linge...
# 10846  (finish_tags, [sweet orange, mint, vanilla, bl...
# 10861  (finish_tags, [weird heat, caramel note linger...
# 10868  (finish_tags, [harsh, decent length, warm spice])
# 11035    (finish_tags, [medium length, nothing of note])
# 11036  (finish_tags, [no heat, Sweet whisp of strawbe...
# 11106  (finish_tags, [nice spice, lingering, harsh, l...
# 11108  (finish_tags, [burn, harsh, decent length, lon...
# 11157  (finish_tags, [smooth, loads of grapes, sweet ...
# 11162        (finish_tags, [sweet, oaky, Medium length])
# 11165  (finish_tags, [shorter, hotter, medium length,...
# 11264  (finish_tags, [balanced, not too sweet, not to...
# 11293  (finish_tags, [solid, uncomplicated, harsh cha...
# 11321  (finish_tags, [oak, wood related sweet flavors...
# 11398        (finish_tags, [Nice long cinnamon, Bitter])
# 11427  (finish_tags, [Oaky tannins, nothing lingers, ...
# 11518  (finish_tags, [yeasty, rustic, herbal, dry, ba...
# 11568            (finish_tags, [oak, allspice, Tobacco])
# 11794  (finish_tags, [spicy kick, heat, long lasting,...
# 11816  (finish_tags, [sugary, caramel oak, vanilla ex...
# 12051             (finish_tags, [oak, Medium-long, rye])
# 12135                                  (finish_tags, [])
# 12329                                  (finish_tags, [])

# %%
#whiskey_reviews_wclusters
