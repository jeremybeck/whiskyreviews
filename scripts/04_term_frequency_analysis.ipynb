# %% [markdown]
# # Introduction

# %% [markdown]
# In this notebook I will be exploring the text structure of Reddit whisky reviews stored at

# %% [markdown]
# # Imports/Setup

# %%
import os
import pandas as pd
import numpy as np
import pymongo
import spacy
from collections import Counter
from gensim.models import TfidfModel, LsiModel
from gensim.corpora import Dictionary
# Out:
# /usr/local/anaconda/lib/python3.6/importlib/_bootstrap.py:219: RuntimeWarning: numpy.dtype size changed, may indicate binary incompatibility. Expected 96, got 88
#   return f(*args, **kwds)
# /usr/local/anaconda/lib/python3.6/importlib/_bootstrap.py:219: RuntimeWarning: numpy.ufunc size changed, may indicate binary incompatibility. Expected 192, got 176
#   return f(*args, **kwds)
# /usr/local/anaconda/lib/python3.6/importlib/_bootstrap.py:219: RuntimeWarning: numpy.dtype size changed, may indicate binary incompatibility. Expected 96, got 88
#   return f(*args, **kwds)
# /usr/local/anaconda/lib/python3.6/importlib/_bootstrap.py:219: RuntimeWarning: numpy.ufunc size changed, may indicate binary incompatibility. Expected 192, got 176
#   return f(*args, **kwds)

# %%
# !sudo python -m spacy download en
nlp = spacy.load('en')
# Out:
# /usr/local/anaconda/lib/python3.6/importlib/_bootstrap.py:219: RuntimeWarning: numpy.dtype size changed, may indicate binary incompatibility. Expected 96, got 88
#   return f(*args, **kwds)
# /usr/local/anaconda/lib/python3.6/importlib/_bootstrap.py:219: RuntimeWarning: numpy.ufunc size changed, may indicate binary incompatibility. Expected 192, got 176
#   return f(*args, **kwds)
# /usr/local/anaconda/lib/python3.6/importlib/_bootstrap.py:219: RuntimeWarning: numpy.dtype size changed, may indicate binary incompatibility. Expected 96, got 88
#   return f(*args, **kwds)
# /usr/local/anaconda/lib/python3.6/importlib/_bootstrap.py:219: RuntimeWarning: numpy.ufunc size changed, may indicate binary incompatibility. Expected 192, got 176
#   return f(*args, **kwds)
# Requirement already satisfied: en_core_web_sm==2.0.0 from https://github.com/explosion/spacy-models/releases/download/en_core_web_sm-2.0.0/en_core_web_sm-2.0.0.tar.gz#egg=en_core_web_sm==2.0.0 in /usr/local/anaconda/lib/python3.6/site-packages (2.0.0)
# You are using pip version 18.1, however version 19.1.1 is available.
# You should consider upgrading via the 'pip install --upgrade pip' command.
#
#     Linking successful
#     /usr/local/anaconda/lib/python3.6/site-packages/en_core_web_sm -->
#     /usr/local/anaconda/lib/python3.6/site-packages/spacy/data/en
#
#     You can now load the model via spacy.load('en')
# /usr/local/anaconda/lib/python3.6/importlib/_bootstrap.py:219: RuntimeWarning: numpy.dtype size changed, may indicate binary incompatibility. Expected 96, got 88
#   return f(*args, **kwds)
# /usr/local/anaconda/lib/python3.6/importlib/_bootstrap.py:219: RuntimeWarning: numpy.ufunc size changed, may indicate binary incompatibility. Expected 192, got 176
#   return f(*args, **kwds)

# %% [markdown]
# # Data Load

# %% [markdown]
# # WhiskyReviews Database Connection

# %%
client = pymongo.MongoClient("mongodb://whiskyadmin:%s@whiskyreviews-shard-00-00-mvfds.mongodb.net:27017,whiskyreviews-shard-00-01-mvfds.mongodb.net:27017,whiskyreviews-shard-00-02-mvfds.mongodb.net:27017/test?ssl=true&replicaSet=WhiskyReviews-shard-0&authSource=admin&retryWrites=true" % (os.getenv('mongopw')))
reddit_reviews = client.reddit_reviews

# %%
reddit_reviews.list_collection_names()
# Out:
# ['parsed', 'submissions']

# %%
parsed = reddit_reviews['parsed']

# %%
documents = [x for x in parsed.find()]

# %%
len(documents)
# Out:
# 31126

# %%
documents[0]
# Out:
# {'_id': '54e266b4abda4e278055f0a3254b0ef2',
#  'tokens': ['wife',
#   'trip',
#   'thailand',
#   'meet',
#   'family',
#   'seen',
#   'plenty',
#   'whisky',
#   'mostly',
#   'jw',
#   'one',
#   'stood',
#   'rest',
#   '100',
#   'pipers',
#   'something',
#   'seen',
#   'seems',
#   'quite',
#   'following',
#   'blend',
#   '40',
#   'alcohol',
#   'volume',
#   '35cl',
#   '220',
#   'baht',
#   '$',
#   '8',
#   'canadian',
#   'got',
#   'novelty',
#   'suspect',
#   'thai',
#   'equivalent',
#   'chivas',
#   'glenfiddich',
#   '12',
#   'colour',
#   'caramel',
#   'suspect',
#   'artificially',
#   'coloured',
#   'nose',
#   'tiger',
#   'balm',
#   'hands',
#   'may',
#   'way',
#   'alcohol',
#   'little',
#   'bit',
#   'leather',
#   'hints',
#   'sweetness',
#   'palate',
#   'bland',
#   'taste',
#   'almost',
#   'nothing',
#   'really',
#   'bit',
#   'woody',
#   'flavour',
#   'promise',
#   'leather',
#   'sweetness',
#   'nose',
#   'gone',
#   'finish',
#   'short',
#   'devoid',
#   'anything',
#   'alcohol',
#   'reminds',
#   'jw',
#   'red',
#   'cheap',
#   'rye',
#   'dad',
#   'drank',
#   'kid',
#   'bought',
#   'primarily',
#   'novelty',
#   'think',
#   'waste',
#   'something',
#   'seek',
#   '68',
#   '100',
#   'ps',
#   'yes',
#   'photo',
#   'essay',
#   'drinking',
#   'scotch'],
#  'lemmas': ['wife',
#   'trip',
#   'thailand',
#   'meet',
#   'family',
#   'see',
#   'plenty',
#   'whisky',
#   'mostly',
#   'jw',
#   'one',
#   'stand',
#   'rest',
#   '100',
#   'piper',
#   'something',
#   'see',
#   'seem',
#   'quite',
#   'follow',
#   'blend',
#   '40',
#   'alcohol',
#   'volume',
#   '35cl',
#   '220',
#   'baht',
#   '$',
#   '8',
#   'canadian',
#   'get',
#   'novelty',
#   'suspect',
#   'thai',
#   'equivalent',
#   'chivas',
#   'glenfiddich',
#   '12',
#   'colour',
#   'caramel',
#   'suspect',
#   'artificially',
#   'colour',
#   'nose',
#   'tiger',
#   'balm',
#   'hand',
#   'may',
#   'way',
#   'alcohol',
#   'little',
#   'bit',
#   'leather',
#   'hint',
#   'sweetness',
#   'palate',
#   'bland',
#   'taste',
#   'almost',
#   'nothing',
#   'really',
#   'bit',
#   'woody',
#   'flavour',
#   'promise',
#   'leather',
#   'sweetness',
#   'nose',
#   'go',
#   'finish',
#   'short',
#   'devoid',
#   'anything',
#   'alcohol',
#   'remind',
#   'jw',
#   'red',
#   'cheap',
#   'rye',
#   'dad',
#   'drink',
#   'kid',
#   'buy',
#   'primarily',
#   'novelty',
#   'think',
#   'waste',
#   'something',
#   'seek',
#   '68',
#   '100',
#   'ps',
#   'yes',
#   'photo',
#   'essay',
#   'drink',
#   'scotch']}

# %%
reviews = pd.DataFrame(documents)

# %%
reviews.head()
# Out:
#                                 _id  \
# 0  54e266b4abda4e278055f0a3254b0ef2
# 1  18b5c00c30a244a49bfa15132192417c
# 2  780c90af30b7447090fbc1fc1c857ecf
# 3  f86e6c62559743b4a20d85d0fb2594e8
# 4  3bc513dc90d944439df8b2f6805b7edf
#
#                                               lemmas  \
# 0  [wife, trip, thailand, meet, family, see, plen...
# 1  [1792, series, continue, time, get, rare, stoc...
# 2  [bourbon, review, 48, 1792, 225th, anniversary...
# 3  [1792, review, series, continue, bottle, bond,...
# 4  [week, oak, liquor, cabinet, get, long, await,...
#
#                                               tokens
# 0  [wife, trip, thailand, meet, family, seen, ple...
# 1  [1792, series, continues, time, getting, rare,...
# 2  [bourbon, review, 48, 1792, 225th, anniversary...
# 3  [1792, review, series, continues, bottled, bon...
# 4  [week, oak, liquor, cabinet, got, long, awaite...

# %%
all_words =  [item for sublist in reviews.tokens for item in sublist]

# %%
all_lemmas = [item for sublist in reviews.lemmas for item in sublist]

# %%
word_freq = Counter(all_words)

# %%
lemma_freq = Counter(all_lemmas)

# %%
word_freq.most_common(100)
# Out:
# [('finish', 72892),
#  ('nose', 71168),
#  ('100', 45640),
#  ('oak', 44934),
#  ('like', 44544),
#  ('sweet', 42058),
#  ('taste', 40747),
#  ('whisky', 37718),
#  ('one', 35166),
#  ('vanilla', 35103),
#  ('notes', 34646),
#  ('bit', 32341),
#  ('palate', 30576),
#  ('really', 30461),
#  ('good', 30380),
#  ('abv', 29744),
#  ('review', 29612),
#  ('sherry', 28236),
#  ('cask', 28086),
#  ('bottle', 25912),
#  ('peat', 25670),
#  ('bourbon', 25046),
#  ('would', 24691),
#  ('smoke', 24674),
#  ('malt', 23688),
#  ('light', 23109),
#  ('caramel', 22699),
#  ('well', 22085),
#  ('score', 21705),
#  ('spice', 21527),
#  ('honey', 21360),
#  ('much', 21183),
#  ('old', 21119),
#  ('little', 21061),
#  ('nice', 20404),
#  ('|', 20233),
#  ('time', 20009),
#  ('year', 19998),
#  ('fruit', 19973),
#  ('quite', 19844),
#  ('10', 19742),
#  ('first', 18707),
#  ('$', 18615),
#  ('pepper', 17921),
#  ('long', 17890),
#  ('nbsp', 17256),
#  ('12', 17255),
#  ('rye', 17065),
#  ('water', 16435),
#  ('color', 16410),
#  ('years', 16153),
#  ('still', 15989),
#  ('get', 15771),
#  ('cinnamon', 15554),
#  ('price', 15294),
#  ('chocolate', 15010),
#  ('wood', 15008),
#  ('scotch', 14862),
#  ('medium', 14594),
#  ('single', 14358),
#  ('dram', 14321),
#  ('think', 13904),
#  ('note', 13633),
#  ('great', 13182),
#  ('sugar', 13080),
#  ('5', 13053),
#  ('dark', 13009),
#  ('sweetness', 12957),
#  ('u', 12809),
#  ('orange', 12704),
#  ('reviews', 12434),
#  ('also', 12391),
#  ('apple', 12381),
#  ('=', 12207),
#  ('something', 12122),
#  ('dry', 11821),
#  ('lot', 11751),
#  ('though', 11687),
#  ('better', 11398),
#  ('lemon', 11368),
#  ('sample', 11285),
#  ('overall', 11283),
#  ('2', 11233),
#  ('casks', 11168),
#  ('citrus', 10862),
#  ('1', 10857),
#  ('proof', 10824),
#  ('floral', 10726),
#  ('3', 10687),
#  ('spicy', 10625),
#  ('barrel', 10478),
#  ('red', 10473),
#  ('colour', 10135),
#  ('see', 10094),
#  ('black', 10070),
#  ('buy', 9987),
#  ('whiskey', 9955),
#  ('back', 9883),
#  ('strength', 9825),
#  ('way', 9742)]

# %%
lemma_freq.most_common(100)
# Out:
# [('finish', 79217),
#  ('nose', 72261),
#  ('taste', 53283),
#  ('note', 48740),
#  ('review', 47554),
#  ('like', 47344),
#  ('sweet', 45753),
#  ('100', 45640),
#  ('whisky', 45426),
#  ('oak', 45374),
#  ('good', 44084),
#  ('bottle', 41716),
#  ('cask', 39404),
#  ('one', 36907),
#  ('year', 36151),
#  ('vanilla', 35149),
#  ('bit', 32558),
#  ('get', 31147),
#  ('peat', 30988),
#  ('palate', 30634),
#  ('really', 30461),
#  ('abv', 29744),
#  ('spice', 29251),
#  ('fruit', 29025),
#  ('sherry', 28270),
#  ('malt', 28259),
#  ('smoke', 27339),
#  ('bourbon', 27064),
#  ('light', 25401),
#  ('old', 25071),
#  ('would', 24691),
#  ('score', 23724),
#  ('caramel', 22989),
#  ('well', 22594),
#  ('time', 22101),
#  ('go', 22022),
#  ('honey', 21791),
#  ('dry', 21209),
#  ('much', 21183),
#  ('little', 21062),
#  ('nice', 20766),
#  ('lot', 20342),
#  ('|', 20233),
#  ('quite', 19844),
#  ('10', 19765),
#  ('apple', 19361),
#  ('try', 18923),
#  ('long', 18801),
#  ('first', 18712),
#  ('$', 18615),
#  ('pepper', 18542),
#  ('think', 18436),
#  ('make', 18227),
#  ('rye', 17900),
#  ('water', 17527),
#  ('12', 17270),
#  ('nbsp', 17256),
#  ('color', 17002),
#  ('price', 16992),
#  ('dram', 16684),
#  ('still', 16476),
#  ('scotch', 16332),
#  ('come', 15691),
#  ('cinnamon', 15554),
#  ('sample', 15321),
#  ('wood', 15224),
#  ('chocolate', 15111),
#  ('age', 15003),
#  ('medium', 14633),
#  ('barrel', 14628),
#  ('dark', 14423),
#  ('single', 14365),
#  ('buy', 14321),
#  ('flavor', 14063),
#  ('orange', 13908),
#  ('say', 13697),
#  ('sugar', 13570),
#  ('great', 13509),
#  ('drink', 13240),
#  ('see', 13091),
#  ('5', 13053),
#  ('sweetness', 12957),
#  ('find', 12955),
#  ('u', 12809),
#  ('also', 12391),
#  ('lemon', 12263),
#  ('=', 12207),
#  ('something', 12155),
#  ('hint', 12128),
#  ('give', 11991),
#  ('though', 11690),
#  ('cherry', 11599),
#  ('overall', 11284),
#  ('know', 11274),
#  ('2', 11233),
#  ('spicy', 11083),
#  ('distillery', 11078),
#  ('proof', 11007),
#  ('1', 10870),
#  ('citrus', 10869)]

# %%
gensim_dict = Dictionary(reviews.lemmas)

# %%
print(gensim_dict)
# Out:
# Dictionary(41525 unique tokens: ['$', '100', '12', '220', '35cl']...)

# %%
gensim_dict.filter_extremes(no_above=0.75, no_below=20)

# %%
print(gensim_dict)
# Out:
# Dictionary(8368 unique tokens: ['$', '100', '12', '220', '35cl']...)

# %%
corpus = [gensim_dict.doc2bow(text) for text in reviews.lemmas]

# %%
model = TfidfModel(corpus)

# %%
reviews['tfidf_vector'] = [model[x] for x in corpus]

# %%
reviews.head(20)
# Out:
#                                  _id  \
# 0   54e266b4abda4e278055f0a3254b0ef2
# 1   18b5c00c30a244a49bfa15132192417c
# 2   780c90af30b7447090fbc1fc1c857ecf
# 3   f86e6c62559743b4a20d85d0fb2594e8
# 4   3bc513dc90d944439df8b2f6805b7edf
# 5   26ba87ecb3d840de8e8231e8923aa334
# 6   ad782e77550743d69d77b766c0d8bae6
# 7   fd6aa09698c14a259e65e2ef4cc971e9
# 8   18686c2d01eb42d1b71c8927becb6a77
# 9   efbe66ef04a44d73af78fc5c90b7ce19
# 10  a271c39775c045c99e0a4020c4f120ed
# 11  b38b5ff065214201bc6fb040b18a1dcc
# 12  58f919a7ef0a4b7a9fc4385242505544
# 13  c18d9847389545e180832d08fa8afd6d
# 14  dfe9115b663149cdb2f958b11018ceec
# 15  ee80799f98cf40788d3c5102a37e11ba
# 16  7ee52dcb9b7d46529a2376e675f31938
# 17  bcecc84bcf2b45b0951fadcd9ea2f4d5
# 18  ada56153ecdd4066b50aae74d46de1f6
# 19  cf43bcd6ceb9454f9953adec98158d00
#
#                                                lemmas  \
# 0   [wife, trip, thailand, meet, family, see, plen...
# 1   [1792, series, continue, time, get, rare, stoc...
# 2   [bourbon, review, 48, 1792, 225th, anniversary...
# 3   [1792, review, series, continue, bottle, bond,...
# 4   [week, oak, liquor, cabinet, get, long, await,...
# 5   [1792, full, proof, price, approx, $, 45, abv,...
# 6                                  [>, 69, 100, nice]
# 7   [review, 9, 11, 1792, threesome, tap, review, ...
# 8   [regular, 1792, inoffensive, plain, bourbon, b...
# 9   [pick, earlier, week, crack, right, away, dunn...
# 10  [review, sample, provide, u, sirabra, 1792, fu...
# 11  [review, 25, 1792, full, proof, next, review, ...
# 12  [ask, opinion, good, bargain, bourbon, availab...
# 13  [mystery, sample, pick, pour, wife, tasting, n...
# 14  [mystery, sample, pick, pour, wife, tasting, n...
# 15  [whiskey, network, review, 37, r, bourbon, rev...
# 16  [happy, friday, everyone, community, review, d...
# 17  [since, sample, think, put, together, rest, gl...
# 18  [​, whiskey, network, review, 212|, r, bourbon...
# 19  [thank, friend, cliff, share, dram, one, miss,...
#
#                                                tokens  \
# 0   [wife, trip, thailand, meet, family, seen, ple...
# 1   [1792, series, continues, time, getting, rare,...
# 2   [bourbon, review, 48, 1792, 225th, anniversary...
# 3   [1792, review, series, continues, bottled, bon...
# 4   [week, oak, liquor, cabinet, got, long, awaite...
# 5   [1792, full, proof, price, approx, $, 45, abv,...
# 6                                  [>, 69, 100, nice]
# 7   [reviews, 9, 11, 1792, threesome, tap, review,...
# 8   [regular, 1792, inoffensive, plain, bourbon, b...
# 9   [picked, earlier, week, cracked, right, away, ...
# 10  [review, sample, provided, u, sirabra, 1792, f...
# 11  [review, 25, 1792, full, proof, next, reviews,...
# 12  [ask, opinion, best, bargain, bourbon, availab...
# 13  [mystery, sample, picked, poured, wife, tastin...
# 14  [mystery, sample, picked, poured, wife, tastin...
# 15  [whiskey, network, review, 37, r, bourbon, rev...
# 16  [happy, friday, everyone, community, review, d...
# 17  [since, samples, thought, put, together, reste...
# 18  [​, whiskey, network, review, 212|, r, bourbon...
# 19  [thanks, friend, cliff, sharing, dram, one, mi...
#
#                                          tfidf_vector
# 0   [(0, 0.03412816814276638), (1, 0.0175051348036...
# 1   [(7, 0.11693062811468903), (9, 0.0303607237337...
# 2   [(1, 0.007146252427824452), (13, 0.03518818716...
# 3   [(0, 0.02194097594289072), (1, 0.0056270195926...
# 4   [(1, 0.004759590876690336), (7, 0.131373865310...
# 5   [(0, 0.03992361940043558), (13, 0.025208147869...
# 6   [(1, 0.07238990168298674), (296, 0.24947556099...
# 7   [(2, 0.015069043142827893), (8, 0.041280891136...
# 8   [(0, 0.040579288579111826), (1, 0.010407032599...
# 9   [(0, 0.02274045708610662), (1, 0.0058320558713...
# 10  [(1, 0.010962103325067389), (44, 0.02579960402...
# 11  [(1, 0.004319879152782838), (5, 0.024490221117...
# 12  [(0, 0.04197668308306831), (2, 0.0243890295226...
# 13  [(7, 0.06390751152895247), (18, 0.039456234063...
# 14  [(8, 0.0648643159086897), (55, 0.1379581577372...
# 15  [(7, 0.09621620861274971), (16, 0.037189047716...
# 16  [(1, 0.011757503637229902), (43, 0.02480177302...
# 17  [(0, 0.04780742749414402), (13, 0.015093029134...
# 18  [(0, 0.013955432408573274), (7, 0.019757643003...
# 19  [(1, 0.0044910501782018004), (7, 0.02479232507...

# %%
gensim_lsi = LsiModel(corpus, id2word=gensim_dict, num_topics=100)

# %%
reviews['lsi_100'] = [gensim_lsi[x] for x in corpus]

# %%
reviews.head()
# Out:
#                                 _id  \
# 0  54e266b4abda4e278055f0a3254b0ef2
# 1  18b5c00c30a244a49bfa15132192417c
# 2  780c90af30b7447090fbc1fc1c857ecf
# 3  f86e6c62559743b4a20d85d0fb2594e8
# 4  3bc513dc90d944439df8b2f6805b7edf
#
#                                               lemmas  \
# 0  [wife, trip, thailand, meet, family, see, plen...
# 1  [1792, series, continue, time, get, rare, stoc...
# 2  [bourbon, review, 48, 1792, 225th, anniversary...
# 3  [1792, review, series, continue, bottle, bond,...
# 4  [week, oak, liquor, cabinet, get, long, await,...
#
#                                               tokens  \
# 0  [wife, trip, thailand, meet, family, seen, ple...
# 1  [1792, series, continues, time, getting, rare,...
# 2  [bourbon, review, 48, 1792, 225th, anniversary...
# 3  [1792, review, series, continues, bottled, bon...
# 4  [week, oak, liquor, cabinet, got, long, awaite...
#
#                                         tfidf_vector  \
# 0  [(0, 0.03412816814276638), (1, 0.0175051348036...
# 1  [(7, 0.11693062811468903), (9, 0.0303607237337...
# 2  [(1, 0.007146252427824452), (13, 0.03518818716...
# 3  [(0, 0.02194097594289072), (1, 0.0056270195926...
# 4  [(1, 0.004759590876690336), (7, 0.131373865310...
#
#                                              lsi_100
# 0  [(0, 3.33971128333082), (1, -0.284198568612503...
# 1  [(0, 11.212749450229037), (1, 1.17891267756165...
# 2  [(0, 6.194591081511533), (1, 0.188943688210547...
# 3  [(0, 11.30827134868932), (1, 1.084815162085012...
# 4  [(0, 14.649387174162893), (1, 1.20498560381070...

# %%
reviews.to_pickle(os.getenv('DOMINO_WORKING_DIR') + '/data/processed/reviews_vectorized.pkl')

# %% [markdown]
# ## Save Gensim Assets

# %%
gensim_dict.save(os.getenv('DOMINO_WORKING_DIR') + '/models/gensim_lemma.dictionary')
model.save(os.getenv('DOMINO_WORKING_DIR') + '/models/lemma_tfidf.genmod')
gensim_lsi.save(os.getenv('DOMINO_WORKING_DIR') + '/models/lsi100_lemma.genmod')

# %% [markdown]
# ## Add Fields to MongoDB

# %% [markdown]
# This code isn't working yet due to encoding of vectors being written into MongoDB.  I need to look into that and decide how to proceed.

# %%
#test case
row = reviews.loc[0]

# %%
errors = []

i=0

for doc in documents:
    id = doc['_id']
    lsi_vec = reviews[reviews._id == id].lsi_100
    tfidf_vec = reviews[reviews._id == id].tfidf_vector
    
    try:
        parsed.update({"_id": id}, {"$set": {"lsi_100": lis_vec, "tfidf_vec": tfidf_vec}})
    except:
        errors.append(id)
    
    
    if i%1000 == 0:
        print('Iteration Completed:', i)
        
        
    i+=1
# Out:
# Iteration Completed: 0
# Iteration Completed: 1000
# Iteration Completed: 2000
# Iteration Completed: 3000
# Iteration Completed: 4000
# Iteration Completed: 5000
# Iteration Completed: 6000
# Iteration Completed: 7000
# Iteration Completed: 8000
# Iteration Completed: 9000
# Iteration Completed: 10000
# Iteration Completed: 11000
# Iteration Completed: 12000
# Iteration Completed: 13000
# Iteration Completed: 14000
# Iteration Completed: 15000
# Iteration Completed: 16000
# Iteration Completed: 17000
# Iteration Completed: 18000
# Iteration Completed: 19000
# Iteration Completed: 20000
# Iteration Completed: 21000
# Iteration Completed: 22000
# Iteration Completed: 23000
# Iteration Completed: 24000
# Iteration Completed: 25000
# Iteration Completed: 26000
# Iteration Completed: 27000
# Iteration Completed: 28000
# Iteration Completed: 29000
# Iteration Completed: 30000
# Iteration Completed: 31000
